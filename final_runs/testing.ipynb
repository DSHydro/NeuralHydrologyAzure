# %%
from neuralhydrology.nh_run import start_run, eval_run, finetune
from pathlib import Path
import pandas as pd
import pickle
import numpy as np
import yaml

# %%
RUN_DIR = Path("./runs")

# %%
# Find all directories starting with 'precip'
precip_dirs = [d for d in RUN_DIR.iterdir() if d.is_dir() and d.name.startswith("precip")]

print(f"Found {len(precip_dirs)} directories: {[d.name for d in precip_dirs]}")
# Out:
# Found 120 directories: ['precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_222_2904_110606', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_111_2904_110014', 'precip_prcp_mm_day_prcp_chirps_mm_day_seed_777_2904_083014', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_222_2904_084721', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_091010', 'precip_prcp_mswep_mm_day_seed_333_2804_223907', 'precip_prcp_mswep_mm_day_seed_222_2804_223324', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_010934', 'precip_prcp_gauge_mm_day_seed_777_2302_080217', 'precip_prcp_chirps_mm_day_seed_777_2904_074449', 'precip_prcp_gauge_mm_day_seed_666_2302_075627', 'precip_prcp_mm_day_seed_444_2202_190226', 'precip_prcp_mm_day_prcp_gauge_mm_day_seed_888_2302_091905', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_131125', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_013333', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_104233', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_123501', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_004557', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_555_2904_112344', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_004009', 'precip_prcp_gauge_mm_day_seed_222_2202_195846', 'precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_888_2904_100720', 'precip_prcp_chirps_mm_day_seed_666_2904_073913', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_005739', 'precip_prcp_chirps_mm_day_seed_222_2904_071648', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_444_2804_234741', 'precip_prcp_mm_day_seed_555_2302_064058', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_114732', 'precip_prcp_mswep_mm_day_seed_555_2804_225032', 'precip_prcp_mswep_mm_day_seed_111_2804_222722', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_003420', 'precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_666_2904_095554', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_555_2904_090427', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_012732', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_888_2904_001101', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_012130', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_444_2904_085845', 'precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_555_2904_095011', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_121120', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_120525', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_222_2904_101859', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_122903', 'precip_prcp_gauge_mm_day_seed_444_2202_201003', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_130523', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_333_2904_002831', 'precip_prcp_mm_day_prcp_chirps_mm_day_seed_444_2904_081305', 'precip_prcp_mm_day_prcp_gauge_mm_day_seed_333_2202_211306', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_111_2904_084139', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_333_2804_234152', 'precip_prcp_gauge_mm_day_seed_555_2302_075038', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_666_2904_112941', 'precip_prcp_gauge_mm_day_seed_888_2302_080806', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_125314', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_122309', 'precip_prcp_mm_day_seed_888_2302_065823', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_222_2804_233604', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_333_2904_111159', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_777_2904_113538', 'precip_prcp_mm_day_prcp_chirps_mm_day_seed_555_2904_081848' ...

# %%
for run_dir in precip_dirs:

    # Skip if test folder already exists
    if (run_dir / "test").exists():
        print(f"Skipping {run_dir.name} — test folder already exists")
        continue

    config_path = run_dir / "config.yml"
    
    if not config_path.exists():
        print(f"Skipping {run_dir.name} — no config.yml found")
        continue
    
    print(f"\nProcessing {run_dir.name}...")
    
    # Read the config
    with open(config_path, 'r') as f:
        content = f.read()
    
    # Only add if not already present
    if "test_start_date" not in content:
        with open(config_path, 'a') as f:
            f.write("\ntest_start_date: 01/10/2009")
        print(f"  Added test_start_date")
    else:
        print(f"  test_start_date already present, skipping")

    if "test_end_date" not in content:
        with open(config_path, 'a') as f:
            f.write("\ntest_end_date: 30/09/2019")
        print(f"  Added test_end_date")
    else:
        print(f"  test_end_date already present, skipping")

    # Run evaluation
    print(f"  Running eval_run...")
    eval_run(run_dir=run_dir, period="test")
    print(f"  Done!")

print("\nAll runs completed!")
# Out:
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_222_2904_110606 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_111_2904_110014 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_777_2904_083014 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_222_2904_084721 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_091010 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_333_2804_223907 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_222_2804_223324 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_010934 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_777_2302_080217 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_seed_777_2904_074449 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_666_2302_075627 — test folder already exists
# Skipping precip_prcp_mm_day_seed_444_2202_190226 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_888_2302_091905 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_131125 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_013333 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_104233 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_123501 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_004557 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_555_2904_112344 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_004009 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_222_2202_195846 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_888_2904_100720 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_seed_666_2904_073913 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_005739 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_seed_222_2904_071648 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_444_2804_234741 — test folder already exists
# Skipping precip_prcp_mm_day_seed_555_2302_064058 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_114732 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_555_2804_225032 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_111_2804_222722 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_003420 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_666_2904_095554 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_555_2904_090427 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_012732 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_888_2904_001101 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_012130 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_444_2904_085845 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_555_2904_095011 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_121120 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_120525 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_222_2904_101859 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_122903 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_444_2202_201003 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_130523 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_333_2904_002831 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_444_2904_081305 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_333_2202_211306 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_111_2904_084139 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_333_2804_234152 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_555_2302_075038 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_666_2904_112941 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_888_2302_080806 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_125314 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_122309 — test folder already exists
# Skipping precip_prcp_mm_day_seed_888_2302_065823 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_222_2804_233604 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_333_2904_111159 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_777_2904_113538 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_555_2904_081848 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_666_2804_225614 — test folder already exists
# Skipping precip_prcp_mm_day_seed_777_2302_065235 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_666_2302_090714 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_444_2904_094428 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_444_2804_224450 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_555_2302_090117 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_124105 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_121715 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_seed_111_2904_071050 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_222_2202_210721 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_111_2904_075559 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_777_2904_000509 — test folder already exists
# Skipping precip_prcp_mm_day_seed_222_2202_185112 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_444_2202_211851 — test folder already exists
# Skipping precip_prcp_mm_day_seed_333_2202_185649 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_888_2904_083557 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_777_2904_091552 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_444_2904_111752 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_111_2904_101304 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_888_2804_230739 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_555_2904_103638 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_seed_333_2904_072228 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_seed_444_2904_072803 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_115329 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_333_2904_102451 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_888_2904_114135 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_777_2302_091309 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_131729 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_222_2904_080141 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_333_2904_093844 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_888_2904_105420 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_333_2904_080723 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_seed_666_2904_082431 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_777_2904_104827 — test folder already exists
# Skipping precip_prcp_mm_day_seed_666_2302_064647 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_gauge_mm_day_seed_111_2202_210136 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_333_2904_115927 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_888_2904_092134 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_777_2904_100137 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_666_2804_235921 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_333_2904_011532 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_333_2904_085304 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_333_2202_200424 — test folder already exists
# Skipping precip_prcp_mm_day_seed_111_2202_184533 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_010331 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_005149 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_111_2904_092717 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_111_2804_233018 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_seed_555_2804_235330 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_013933 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_002241 — test folder already exists
# Skipping precip_prcp_chirps_mm_day_seed_888_2904_075024 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_001651 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_444_2904_103044 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_125917 — test folder already exists
# Skipping precip_prcp_mswep_mm_day_seed_777_2804_230155 — test folder already exists
# Skipping precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_333_2904_124709 — test folder already exists
# Skipping precip_prcp_gauge_mm_day_seed_111_2202_195308 — test folder already exists
#
# Processing precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_222_2904_093300...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:  18%|█▊        | 2/11 [00:01<00:06,  1.29it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:06<00:00,  1.74it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_seed_555_2904_073338...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:01<00:04,  1.99it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:05<00:00,  2.00it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_014533...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:03,  2.40it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:05<00:00,  2.03it/s]
#   Done!
#
# All runs completed!
