# %%
from pathlib import Path
import sys
import pandas as pd
import torch
import matplotlib.pyplot as plt
import xarray as xr
import yaml
import geopandas as gpd
import contextily as cx
from adjustText import adjust_text
import pickle
from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.nh_run import continue_run
from neuralhydrology.utils.config import Config
from neuralhydrology.evaluation import get_tester, metrics

# %%
# -------- Paths ---------
CONFIG_PATH = Path("./uy_basins.yml")
RUNS_DIR = Path("runs")
PLOTS_DIR = Path("./evaluation_plots")
RUNS_DIR = Path("runs")
PLOTS_DIR = Path("evaluation_plots")
# ATTRIBUTES_FILE= Path('/inputs/data_updated/attributes/attributes_other.csv')

# %%
# by default we assume that you have at least one CUDA-capable NVIDIA GPU or MacOS with Metal support
if torch.cuda.is_available() or torch.backends.mps.is_available():
    start_run(config_file=Path("uy_basins.yml"))

# fall back to CPU-only mode
else:
    start_run(config_file=Path("uy_basins.yml"), gpu=-1)
# Out:
# 2026-02-02 17:24:17,506: Logging to /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/output.log initialized.
# 2026-02-02 17:24:17,507: ### Folder structure created at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417
# 2026-02-02 17:24:17,507: ### Run configurations for ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111
# 2026-02-02 17:24:17,508: experiment_name: ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111
# 2026-02-02 17:24:17,508: run_dir: /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417
# 2026-02-02 17:24:17,509: train_basin_file: filtered_uy_basins.txt
# 2026-02-02 17:24:17,510: validation_basin_file: filtered_uy_basins.txt
# 2026-02-02 17:24:17,511: test_basin_file: filtered_uy_basins.txt
# 2026-02-02 17:24:17,511: train_start_date: 1999-10-01 00:00:00
# 2026-02-02 17:24:17,512: train_end_date: 2008-09-30 00:00:00
# 2026-02-02 17:24:17,512: validation_start_date: 1989-10-01 00:00:00
# 2026-02-02 17:24:17,513: validation_end_date: 1999-09-30 00:00:00
# 2026-02-02 17:24:17,513: seed: 111
# 2026-02-02 17:24:17,514: device: cuda:0
# 2026-02-02 17:24:17,514: validate_every: 1
# 2026-02-02 17:24:17,515: metrics: ['NSE', 'KGE', 'Alpha-NSE', 'Beta-NSE', 'Pearson-r', 'RMSE', 'MSE', 'Beta-KGE']
# 2026-02-02 17:24:17,515: model: cudalstm
# 2026-02-02 17:24:17,516: head: regression
# 2026-02-02 17:24:17,516: hidden_size: 256
# 2026-02-02 17:24:17,517: initial_forget_bias: 5
# 2026-02-02 17:24:17,517: output_dropout: 0.4
# 2026-02-02 17:24:17,518: output_activation: linear
# 2026-02-02 17:24:17,518: optimizer: Adam
# 2026-02-02 17:24:17,519: loss: NSE
# 2026-02-02 17:24:17,519: learning_rate: {0: 0.001}
# 2026-02-02 17:24:17,520: batch_size: 256
# 2026-02-02 17:24:17,520: epochs: 30
# 2026-02-02 17:24:17,521: clip_gradient_norm: 1
# 2026-02-02 17:24:17,521: predict_last_n: 1
# 2026-02-02 17:24:17,521: seq_length: 270
# 2026-02-02 17:24:17,522: num_workers: 4
# 2026-02-02 17:24:17,523: log_interval: 5
# 2026-02-02 17:24:17,523: log_tensorboard: True
# 2026-02-02 17:24:17,524: save_weights_every: 1
# 2026-02-02 17:24:17,524: save_validation_results: True
# 2026-02-02 17:24:17,525: data_dir: mswep_filtered_date_precip_ls
# 2026-02-02 17:24:17,525: dataset: generic
# 2026-02-02 17:24:17,526: dynamic_inputs: ['prcp_mm_day', 'srad_W_m2', 'tmax_C', 'tmin_C']
# 2026-02-02 17:24:17,526: target_variables: ['QObs_mm_d']
# 2026-02-02 17:24:17,527: static_attributes: ['elev_mean', 'slope_mean', 'area_gages2', 'sand_frac', 'silt_frac', 'clay_frac', 'p_mean', 'pet_mean', 'aridity', 'high_prec_dur', 'low_prec_dur']
# 2026-02-02 17:24:17,527: number_of_basins: 11
# 2026-02-02 17:24:17,528: train_dir: /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/train_data
# 2026-02-02 17:24:17,528: img_log_dir: /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/img_log
# 2026-02-02 17:24:17,529: ### Device cuda:0 will be used for training
# 2026-02-02 17:24:17,538: Loading basin data into xarray data set.
# 100%|██████████| 11/11 [00:00<00:00, 31.00it/s]
# 2026-02-02 17:24:17,904: Calculating target variable stds per basin
# 100%|██████████| 11/11 [00:00<00:00, 1558.12it/s]
# 2026-02-02 17:24:17,916: Create lookup table and convert to pytorch tensor
# 100%|██████████| 11/11 [00:00<00:00, 47.38it/s]
# 2026-02-02 17:24:18,176: Validation set to validate every 1 epoch(s), but 'validate_n_random_basins' not set or set to zero. Will validate on the entire validation set.
# # Epoch 1: 100%|██████████| 132/132 [00:07<00:00, 18.18it/s, Loss: 0.0764]
# 2026-02-02 17:24:25,444: Epoch 1 average loss: avg_loss: 0.06523, avg_total_loss: 0.06523
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.52it/s]
# 2026-02-02 17:24:29,818: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch001/validation_metrics.csv
# 2026-02-02 17:24:29,821: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch001/validation_results.p
# 2026-02-02 17:24:29,824: Epoch 1 average validation loss: 0.05879 -- Median validation metrics: avg_loss: 0.05879, NSE: 0.06013, KGE: -0.11549, Alpha-NSE: 0.16679, Beta-NSE: 0.20377, Pearson-r: 0.44734, RMSE: 2.79099, MSE: 7.78964, Beta-KGE: 1.35452
# # Epoch 2: 100%|██████████| 132/132 [00:07<00:00, 18.46it/s, Loss: 0.0162]
# 2026-02-02 17:24:36,976: Epoch 2 average loss: avg_loss: 0.04897, avg_total_loss: 0.04897
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-02-02 17:24:40,990: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch002/validation_metrics.csv
# 2026-02-02 17:24:40,993: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch002/validation_results.p
# 2026-02-02 17:24:40,996: Epoch 2 average validation loss: 0.03863 -- Median validation metrics: avg_loss: 0.03863, NSE: 0.33288, KGE: 0.39153, Alpha-NSE: 0.57745, Beta-NSE: 0.13397, Pearson-r: 0.65111, RMSE: 2.09685, MSE: 4.39677, Beta-KGE: 1.27573
# # Epoch 3: 100%|██████████| 132/132 [00:07<00:00, 18.30it/s, Loss: 0.0370]
# 2026-02-02 17:24:48,211: Epoch 3 average loss: avg_loss: 0.03944, avg_total_loss: 0.03944
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.88it/s]
# 2026-02-02 17:24:52,047: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch003/validation_metrics.csv
# 2026-02-02 17:24:52,050: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch003/validation_results.p
# 2026-02-02 17:24:52,053: Epoch 3 average validation loss: 0.03580 -- Median validation metrics: avg_loss: 0.03580, NSE: 0.45507, KGE: 0.38071, Alpha-NSE: 0.68463, Beta-NSE: 0.13916, Pearson-r: 0.77542, RMSE: 1.72932, MSE: 2.99055, Beta-KGE: 1.27666
# # Epoch 4: 100%|██████████| 132/132 [00:07<00:00, 18.08it/s, Loss: 0.0342]
# 2026-02-02 17:24:59,355: Epoch 4 average loss: avg_loss: 0.03231, avg_total_loss: 0.03231
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.87it/s]
# 2026-02-02 17:25:03,197: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch004/validation_metrics.csv
# 2026-02-02 17:25:03,200: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch004/validation_results.p
# 2026-02-02 17:25:03,203: Epoch 4 average validation loss: 0.03311 -- Median validation metrics: avg_loss: 0.03311, NSE: 0.58194, KGE: 0.55674, Alpha-NSE: 0.89893, Beta-NSE: 0.08413, Pearson-r: 0.80309, RMSE: 1.60654, MSE: 2.58096, Beta-KGE: 1.12859
# # Epoch 5: 100%|██████████| 132/132 [00:07<00:00, 18.28it/s, Loss: 0.0245]
# 2026-02-02 17:25:10,427: Epoch 5 average loss: avg_loss: 0.02884, avg_total_loss: 0.02884
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.87it/s]
# 2026-02-02 17:25:14,278: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch005/validation_metrics.csv
# 2026-02-02 17:25:14,281: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch005/validation_results.p
# 2026-02-02 17:25:14,283: Epoch 5 average validation loss: 0.03081 -- Median validation metrics: avg_loss: 0.03081, NSE: 0.56790, KGE: 0.61878, Alpha-NSE: 0.85961, Beta-NSE: 0.14619, Pearson-r: 0.81974, RMSE: 1.62892, MSE: 2.65340, Beta-KGE: 1.28451
# # Epoch 6: 100%|██████████| 132/132 [00:07<00:00, 18.29it/s, Loss: 0.0156]
# 2026-02-02 17:25:21,504: Epoch 6 average loss: avg_loss: 0.02744, avg_total_loss: 0.02744
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.86it/s]
# 2026-02-02 17:25:25,360: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch006/validation_metrics.csv
# 2026-02-02 17:25:25,364: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch006/validation_results.p
# 2026-02-02 17:25:25,366: Epoch 6 average validation loss: 0.03310 -- Median validation metrics: avg_loss: 0.03310, NSE: 0.46512, KGE: 0.35535, Alpha-NSE: 0.86027, Beta-NSE: 0.25868, Pearson-r: 0.83110, RMSE: 1.90824, MSE: 3.64137, Beta-KGE: 1.52044
# # Epoch 7: 100%|██████████| 132/132 [00:07<00:00, 17.40it/s, Loss: 0.0192]
# 2026-02-02 17:25:32,954: Epoch 7 average loss: avg_loss: 0.02501, avg_total_loss: 0.02501
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-02-02 17:25:36,986: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch007/validation_metrics.csv
# 2026-02-02 17:25:36,989: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch007/validation_results.p
# 2026-02-02 17:25:36,992: Epoch 7 average validation loss: 0.02924 -- Median validation metrics: avg_loss: 0.02924, NSE: 0.60246, KGE: 0.56502, Alpha-NSE: 0.97364, Beta-NSE: 0.10668, Pearson-r: 0.81743, RMSE: 1.73284, MSE: 3.00274, Beta-KGE: 1.16755
# # Epoch 8: 100%|██████████| 132/132 [00:07<00:00, 18.12it/s, Loss: 0.0266]
# 2026-02-02 17:25:44,281: Epoch 8 average loss: avg_loss: 0.02396, avg_total_loss: 0.02396
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.86it/s]
# 2026-02-02 17:25:48,141: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch008/validation_metrics.csv
# 2026-02-02 17:25:48,144: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch008/validation_results.p
# 2026-02-02 17:25:48,147: Epoch 8 average validation loss: 0.03327 -- Median validation metrics: avg_loss: 0.03327, NSE: 0.56499, KGE: 0.60636, Alpha-NSE: 1.01700, Beta-NSE: 0.09657, Pearson-r: 0.81042, RMSE: 2.02646, MSE: 4.10656, Beta-KGE: 1.23384
# # Epoch 9: 100%|██████████| 132/132 [00:07<00:00, 18.16it/s, Loss: 0.0266]
# 2026-02-02 17:25:55,417: Epoch 9 average loss: avg_loss: 0.02297, avg_total_loss: 0.02297
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.86it/s]
# 2026-02-02 17:25:59,272: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch009/validation_metrics.csv
# 2026-02-02 17:25:59,276: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch009/validation_results.p
# 2026-02-02 17:25:59,278: Epoch 9 average validation loss: 0.03225 -- Median validation metrics: avg_loss: 0.03225, NSE: 0.56809, KGE: 0.50068, Alpha-NSE: 0.90905, Beta-NSE: 0.11260, Pearson-r: 0.80271, RMSE: 2.01924, MSE: 4.07734, Beta-KGE: 1.24633
# # Epoch 10: 100%|██████████| 132/132 [00:07<00:00, 17.94it/s, Loss: 0.0148]
# 2026-02-02 17:26:06,640: Epoch 10 average loss: avg_loss: 0.02288, avg_total_loss: 0.02288
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.86it/s]
# 2026-02-02 17:26:10,503: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch010/validation_metrics.csv
# 2026-02-02 17:26:10,506: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch010/validation_results.p
# 2026-02-02 17:26:10,509: Epoch 10 average validation loss: 0.04018 -- Median validation metrics: avg_loss: 0.04018, NSE: 0.50501, KGE: 0.24028, Alpha-NSE: 1.09580, Beta-NSE: 0.26376, Pearson-r: 0.82193, RMSE: 2.00390, MSE: 4.01563, Beta-KGE: 1.54782
# # Epoch 11: 100%|██████████| 132/132 [00:07<00:00, 18.15it/s, Loss: 0.0226]
# 2026-02-02 17:26:17,784: Epoch 11 average loss: avg_loss: 0.02120, avg_total_loss: 0.02120
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.86it/s]
# 2026-02-02 17:26:21,646: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch011/validation_metrics.csv
# 2026-02-02 17:26:21,649: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch011/validation_results.p
# 2026-02-02 17:26:21,651: Epoch 11 average validation loss: 0.02831 -- Median validation metrics: avg_loss: 0.02831, NSE: 0.63527, KGE: 0.67104, Alpha-NSE: 0.89308, Beta-NSE: -0.02415, Pearson-r: 0.80713, RMSE: 1.85557, MSE: 3.44314, Beta-KGE: 0.96309
# # Epoch 12: 100%|██████████| 132/132 [00:07<00:00, 18.03it/s, Loss: 0.0196]
# 2026-02-02 17:26:28,974: Epoch 12 average loss: avg_loss: 0.02071, avg_total_loss: 0.02071
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.73it/s]
# 2026-02-02 17:26:33,022: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch012/validation_metrics.csv
# 2026-02-02 17:26:33,025: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch012/validation_results.p
# 2026-02-02 17:26:33,028: Epoch 12 average validation loss: 0.02831 -- Median validation metrics: avg_loss: 0.02831, NSE: 0.62149, KGE: 0.65201, Alpha-NSE: 0.78892, Beta-NSE: 0.08225, Pearson-r: 0.81495, RMSE: 1.78642, MSE: 3.19130, Beta-KGE: 1.20329
# # Epoch 13: 100%|██████████| 132/132 [00:07<00:00, 18.07it/s, Loss: 0.0135]
# 2026-02-02 17:26:40,338: Epoch 13 average loss: avg_loss: 0.01985, avg_total_loss: 0.01985
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:26:44,207: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch013/validation_metrics.csv
# 2026-02-02 17:26:44,210: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch013/validation_results.p
# 2026-02-02 17:26:44,214: Epoch 13 average validation loss: 0.04016 -- Median validation metrics: avg_loss: 0.04016, NSE: 0.48155, KGE: 0.40700, Alpha-NSE: 1.05930, Beta-NSE: 0.22092, Pearson-r: 0.81291, RMSE: 2.21230, MSE: 4.89426, Beta-KGE: 1.51802
# # Epoch 14: 100%|██████████| 132/132 [00:07<00:00, 17.99it/s, Loss: 0.0143]
# 2026-02-02 17:26:51,554: Epoch 14 average loss: avg_loss: 0.01949, avg_total_loss: 0.01949
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:26:55,423: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch014/validation_metrics.csv
# 2026-02-02 17:26:55,426: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch014/validation_results.p
# 2026-02-02 17:26:55,429: Epoch 14 average validation loss: 0.04277 -- Median validation metrics: avg_loss: 0.04277, NSE: 0.23629, KGE: 0.45410, Alpha-NSE: 1.08773, Beta-NSE: 0.24439, Pearson-r: 0.82277, RMSE: 2.43450, MSE: 5.92677, Beta-KGE: 1.33697
# # Epoch 15: 100%|██████████| 132/132 [00:07<00:00, 18.10it/s, Loss: 0.0194]
# 2026-02-02 17:27:02,723: Epoch 15 average loss: avg_loss: 0.01834, avg_total_loss: 0.01834
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.82it/s]
# 2026-02-02 17:27:06,634: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch015/validation_metrics.csv
# 2026-02-02 17:27:06,638: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch015/validation_results.p
# 2026-02-02 17:27:06,641: Epoch 15 average validation loss: 0.03150 -- Median validation metrics: avg_loss: 0.03150, NSE: 0.62004, KGE: 0.61016, Alpha-NSE: 1.05983, Beta-NSE: 0.12554, Pearson-r: 0.82583, RMSE: 1.81842, MSE: 3.30665, Beta-KGE: 1.25238
# # Epoch 16: 100%|██████████| 132/132 [00:07<00:00, 17.81it/s, Loss: 0.0072]
# 2026-02-02 17:27:14,056: Epoch 16 average loss: avg_loss: 0.01820, avg_total_loss: 0.01820
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.72it/s]
# 2026-02-02 17:27:18,112: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch016/validation_metrics.csv
# 2026-02-02 17:27:18,115: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch016/validation_results.p
# 2026-02-02 17:27:18,118: Epoch 16 average validation loss: 0.03474 -- Median validation metrics: avg_loss: 0.03474, NSE: 0.51869, KGE: 0.47646, Alpha-NSE: 1.03657, Beta-NSE: 0.14926, Pearson-r: 0.82668, RMSE: 2.08394, MSE: 4.34282, Beta-KGE: 1.27213
# # Epoch 17: 100%|██████████| 132/132 [00:07<00:00, 17.82it/s, Loss: 0.0131]
# 2026-02-02 17:27:25,526: Epoch 17 average loss: avg_loss: 0.01840, avg_total_loss: 0.01840
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:27:29,399: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch017/validation_metrics.csv
# 2026-02-02 17:27:29,402: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch017/validation_results.p
# 2026-02-02 17:27:29,405: Epoch 17 average validation loss: 0.03158 -- Median validation metrics: avg_loss: 0.03158, NSE: 0.60314, KGE: 0.55060, Alpha-NSE: 0.99101, Beta-NSE: 0.14164, Pearson-r: 0.81830, RMSE: 1.64408, MSE: 2.70301, Beta-KGE: 1.33454
# # Epoch 18: 100%|██████████| 132/132 [00:07<00:00, 18.11it/s, Loss: 0.0325]
# 2026-02-02 17:27:36,698: Epoch 18 average loss: avg_loss: 0.01788, avg_total_loss: 0.01788
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:27:40,573: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch018/validation_metrics.csv
# 2026-02-02 17:27:40,576: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch018/validation_results.p
# 2026-02-02 17:27:40,579: Epoch 18 average validation loss: 0.03428 -- Median validation metrics: avg_loss: 0.03428, NSE: 0.61465, KGE: 0.56613, Alpha-NSE: 1.02353, Beta-NSE: 0.15986, Pearson-r: 0.81874, RMSE: 1.83053, MSE: 3.35082, Beta-KGE: 1.35258
# # Epoch 19: 100%|██████████| 132/132 [00:07<00:00, 18.01it/s, Loss: 0.0166]
# 2026-02-02 17:27:47,911: Epoch 19 average loss: avg_loss: 0.01717, avg_total_loss: 0.01717
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:27:51,789: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch019/validation_metrics.csv
# 2026-02-02 17:27:51,792: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch019/validation_results.p
# 2026-02-02 17:27:51,794: Epoch 19 average validation loss: 0.04291 -- Median validation metrics: avg_loss: 0.04291, NSE: 0.39523, KGE: 0.28939, Alpha-NSE: 1.15405, Beta-NSE: 0.24489, Pearson-r: 0.82313, RMSE: 2.30310, MSE: 5.30429, Beta-KGE: 1.58855
# # Epoch 20: 100%|██████████| 132/132 [00:07<00:00, 17.45it/s, Loss: 0.0123]
# 2026-02-02 17:27:59,362: Epoch 20 average loss: avg_loss: 0.01734, avg_total_loss: 0.01734
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.72it/s]
# 2026-02-02 17:28:03,414: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch020/validation_metrics.csv
# 2026-02-02 17:28:03,417: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch020/validation_results.p
# 2026-02-02 17:28:03,420: Epoch 20 average validation loss: 0.04173 -- Median validation metrics: avg_loss: 0.04173, NSE: 0.45022, KGE: 0.38058, Alpha-NSE: 1.19358, Beta-NSE: 0.23465, Pearson-r: 0.81647, RMSE: 2.51252, MSE: 6.31273, Beta-KGE: 1.47154
# # Epoch 21: 100%|██████████| 132/132 [00:07<00:00, 18.04it/s, Loss: 0.0261]
# 2026-02-02 17:28:10,739: Epoch 21 average loss: avg_loss: 0.01651, avg_total_loss: 0.01651
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-02-02 17:28:14,753: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch021/validation_metrics.csv
# 2026-02-02 17:28:14,756: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch021/validation_results.p
# 2026-02-02 17:28:14,759: Epoch 21 average validation loss: 0.03713 -- Median validation metrics: avg_loss: 0.03713, NSE: 0.49902, KGE: 0.45257, Alpha-NSE: 1.02312, Beta-NSE: 0.22178, Pearson-r: 0.82688, RMSE: 2.10172, MSE: 4.41721, Beta-KGE: 1.45594
# # Epoch 22: 100%|██████████| 132/132 [00:07<00:00, 17.86it/s, Loss: 0.0061]
# 2026-02-02 17:28:22,154: Epoch 22 average loss: avg_loss: 0.01619, avg_total_loss: 0.01619
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.84it/s]
# 2026-02-02 17:28:26,033: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch022/validation_metrics.csv
# 2026-02-02 17:28:26,036: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch022/validation_results.p
# 2026-02-02 17:28:26,039: Epoch 22 average validation loss: 0.04106 -- Median validation metrics: avg_loss: 0.04106, NSE: 0.35810, KGE: 0.51381, Alpha-NSE: 1.14041, Beta-NSE: 0.10065, Pearson-r: 0.81191, RMSE: 2.46164, MSE: 6.05968, Beta-KGE: 1.24857
# # Epoch 23: 100%|██████████| 132/132 [00:07<00:00, 18.10it/s, Loss: 0.0159]
# 2026-02-02 17:28:33,335: Epoch 23 average loss: avg_loss: 0.01561, avg_total_loss: 0.01561
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:28:37,211: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch023/validation_metrics.csv
# 2026-02-02 17:28:37,214: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch023/validation_results.p
# 2026-02-02 17:28:37,216: Epoch 23 average validation loss: 0.03906 -- Median validation metrics: avg_loss: 0.03906, NSE: 0.49998, KGE: 0.49129, Alpha-NSE: 1.07476, Beta-NSE: 0.18380, Pearson-r: 0.82971, RMSE: 2.17262, MSE: 4.72029, Beta-KGE: 1.36281
# # Epoch 24: 100%|██████████| 132/132 [00:07<00:00, 18.01it/s, Loss: 0.0155]
# 2026-02-02 17:28:44,550: Epoch 24 average loss: avg_loss: 0.01523, avg_total_loss: 0.01523
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.84it/s]
# 2026-02-02 17:28:48,437: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch024/validation_metrics.csv
# 2026-02-02 17:28:48,441: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch024/validation_results.p
# 2026-02-02 17:28:48,443: Epoch 24 average validation loss: 0.04979 -- Median validation metrics: avg_loss: 0.04979, NSE: 0.30213, KGE: 0.23872, Alpha-NSE: 1.21333, Beta-NSE: 0.26239, Pearson-r: 0.82148, RMSE: 2.59297, MSE: 6.72347, Beta-KGE: 1.50940
# # Epoch 25: 100%|██████████| 132/132 [00:07<00:00, 18.04it/s, Loss: 0.0108]
# 2026-02-02 17:28:55,762: Epoch 25 average loss: avg_loss: 0.01464, avg_total_loss: 0.01464
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.72it/s]
# 2026-02-02 17:28:59,823: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch025/validation_metrics.csv
# 2026-02-02 17:28:59,826: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch025/validation_results.p
# 2026-02-02 17:28:59,829: Epoch 25 average validation loss: 0.03731 -- Median validation metrics: avg_loss: 0.03731, NSE: 0.51217, KGE: 0.58399, Alpha-NSE: 1.09537, Beta-NSE: 0.15345, Pearson-r: 0.82338, RMSE: 1.98382, MSE: 3.93556, Beta-KGE: 1.27976
# # Epoch 26: 100%|██████████| 132/132 [00:07<00:00, 18.04it/s, Loss: 0.0059]
# 2026-02-02 17:29:07,149: Epoch 26 average loss: avg_loss: 0.01523, avg_total_loss: 0.01523
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.84it/s]
# 2026-02-02 17:29:11,031: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch026/validation_metrics.csv
# 2026-02-02 17:29:11,034: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch026/validation_results.p
# 2026-02-02 17:29:11,037: Epoch 26 average validation loss: 0.03304 -- Median validation metrics: avg_loss: 0.03304, NSE: 0.61265, KGE: 0.65843, Alpha-NSE: 1.02650, Beta-NSE: 0.06128, Pearson-r: 0.83216, RMSE: 1.80060, MSE: 3.24214, Beta-KGE: 1.12275
# # Epoch 27: 100%|██████████| 132/132 [00:07<00:00, 17.93it/s, Loss: 0.0094]
# 2026-02-02 17:29:18,403: Epoch 27 average loss: avg_loss: 0.01432, avg_total_loss: 0.01432
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.77it/s]
# 2026-02-02 17:29:22,389: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch027/validation_metrics.csv
# 2026-02-02 17:29:22,392: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch027/validation_results.p
# 2026-02-02 17:29:22,395: Epoch 27 average validation loss: 0.05208 -- Median validation metrics: avg_loss: 0.05208, NSE: 0.20625, KGE: 0.28412, Alpha-NSE: 1.29604, Beta-NSE: 0.27372, Pearson-r: 0.81295, RMSE: 2.40360, MSE: 5.77730, Beta-KGE: 1.48576
# # Epoch 28: 100%|██████████| 132/132 [00:07<00:00, 18.07it/s, Loss: 0.0145]
# 2026-02-02 17:29:29,702: Epoch 28 average loss: avg_loss: 0.01431, avg_total_loss: 0.01431
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:29:33,576: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch028/validation_metrics.csv
# 2026-02-02 17:29:33,579: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch028/validation_results.p
# 2026-02-02 17:29:33,581: Epoch 28 average validation loss: 0.03819 -- Median validation metrics: avg_loss: 0.03819, NSE: 0.49168, KGE: 0.67127, Alpha-NSE: 1.10935, Beta-NSE: 0.06856, Pearson-r: 0.80899, RMSE: 2.04452, MSE: 4.18006, Beta-KGE: 1.15329
# # Epoch 29: 100%|██████████| 132/132 [00:07<00:00, 17.94it/s, Loss: 0.0211]
# 2026-02-02 17:29:40,943: Epoch 29 average loss: avg_loss: 0.01395, avg_total_loss: 0.01395
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.84it/s]
# 2026-02-02 17:29:44,833: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch029/validation_metrics.csv
# 2026-02-02 17:29:44,836: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch029/validation_results.p
# 2026-02-02 17:29:44,839: Epoch 29 average validation loss: 0.03907 -- Median validation metrics: avg_loss: 0.03907, NSE: 0.45741, KGE: 0.45649, Alpha-NSE: 1.10242, Beta-NSE: 0.18440, Pearson-r: 0.82175, RMSE: 2.15916, MSE: 4.66199, Beta-KGE: 1.35413
# # Epoch 30: 100%|██████████| 132/132 [00:07<00:00, 18.02it/s, Loss: 0.0112]
# 2026-02-02 17:29:52,166: Epoch 30 average loss: avg_loss: 0.01396, avg_total_loss: 0.01396
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-02-02 17:29:56,045: Stored metrics at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch030/validation_metrics.csv
# 2026-02-02 17:29:56,048: Stored results at /home/azureuser/sky_workdir/comparing_precip_products/runs/ls_MSWEP_new_precip_correction_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0202_172417/validation/model_epoch030/validation_results.p
# 2026-02-02 17:29:56,050: Epoch 30 average validation loss: 0.04009 -- Median validation metrics: avg_loss: 0.04009, NSE: 0.43181, KGE: 0.47609, Alpha-NSE: 1.14256, Beta-NSE: 0.20906, Pearson-r: 0.81845, RMSE: 2.07962, MSE: 4.32482, Beta-KGE: 1.42101
