# %%
from pathlib import Path
import sys
import pandas as pd
import torch
import matplotlib.pyplot as plt
import xarray as xr
import yaml
import geopandas as gpd
import contextily as cx
from adjustText import adjust_text

from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.nh_run import continue_run
from neuralhydrology.utils.config import Config
from neuralhydrology.evaluation import get_tester, metrics

# %%
# -------- Paths ---------
CONFIG_PATH = Path("./training_MSWEP.yml")
RUNS_DIR = Path("runs")
PLOTS_DIR = Path("./evaluation_plots")
RUNS_DIR = Path("runs")
PLOTS_DIR = Path("evaluation_plots")
# ATTRIBUTES_FILE= Path('/inputs/data_updated/attributes/attributes_other.csv')

# %%
# by default we assume that you have at least one CUDA-capable NVIDIA GPU or MacOS with Metal support
if torch.cuda.is_available() or torch.backends.mps.is_available():
    start_run(config_file=Path("training_MSWEP.yml"))

# fall back to CPU-only mode
else:
    start_run(config_file=Path("training_MSWEP.yml"), gpu=-1)
# Out:
# 2026-01-31 22:55:49,841: Logging to /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/output.log initialized.
# 2026-01-31 22:55:49,841: ### Folder structure created at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549
# 2026-01-31 22:55:49,842: ### Run configurations for corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111
# 2026-01-31 22:55:49,842: experiment_name: corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111
# 2026-01-31 22:55:49,843: run_dir: /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549
# 2026-01-31 22:55:49,843: train_basin_file: basins.txt
# 2026-01-31 22:55:49,844: validation_basin_file: basins.txt
# 2026-01-31 22:55:49,844: test_basin_file: basins.txt
# 2026-01-31 22:55:49,845: train_start_date: 1999-10-01 00:00:00
# 2026-01-31 22:55:49,845: train_end_date: 2008-09-30 00:00:00
# 2026-01-31 22:55:49,846: validation_start_date: 1989-10-01 00:00:00
# 2026-01-31 22:55:49,846: validation_end_date: 1999-09-30 00:00:00
# 2026-01-31 22:55:49,846: seed: 111
# 2026-01-31 22:55:49,847: device: cuda:0
# 2026-01-31 22:55:49,847: validate_every: 1
# 2026-01-31 22:55:49,848: metrics: ['NSE', 'KGE', 'Alpha-NSE', 'Beta-NSE', 'Pearson-r', 'RMSE', 'MSE', 'Beta-KGE']
# 2026-01-31 22:55:49,848: model: cudalstm
# 2026-01-31 22:55:49,849: head: regression
# 2026-01-31 22:55:49,849: hidden_size: 256
# 2026-01-31 22:55:49,850: initial_forget_bias: 5
# 2026-01-31 22:55:49,850: output_dropout: 0.4
# 2026-01-31 22:55:49,851: output_activation: linear
# 2026-01-31 22:55:49,851: optimizer: Adam
# 2026-01-31 22:55:49,852: loss: NSE
# 2026-01-31 22:55:49,852: learning_rate: {0: 0.001}
# 2026-01-31 22:55:49,852: batch_size: 256
# 2026-01-31 22:55:49,853: epochs: 30
# 2026-01-31 22:55:49,853: clip_gradient_norm: 1
# 2026-01-31 22:55:49,854: predict_last_n: 1
# 2026-01-31 22:55:49,854: seq_length: 270
# 2026-01-31 22:55:49,855: num_workers: 4
# 2026-01-31 22:55:49,855: log_interval: 5
# 2026-01-31 22:55:49,855: log_tensorboard: True
# 2026-01-31 22:55:49,856: save_weights_every: 1
# 2026-01-31 22:55:49,856: save_validation_results: True
# 2026-01-31 22:55:49,857: data_dir: filtered_data_gauge_and_corrected_MSWEP
# 2026-01-31 22:55:49,857: dataset: generic
# 2026-01-31 22:55:49,858: dynamic_inputs: ['prcp_mm_day', 'srad_W_m2', 'tmax_C', 'tmin_C', 'prcp_mswep_mm_day']
# 2026-01-31 22:55:49,858: target_variables: ['QObs_mm_d']
# 2026-01-31 22:55:49,859: static_attributes: ['elev_mean', 'slope_mean', 'area_gages2', 'sand_frac', 'silt_frac', 'clay_frac', 'p_mean', 'pet_mean', 'aridity', 'high_prec_dur', 'low_prec_dur']
# 2026-01-31 22:55:49,859: number_of_basins: 11
# 2026-01-31 22:55:49,859: train_dir: /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/train_data
# 2026-01-31 22:55:49,860: img_log_dir: /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/img_log
# 2026-01-31 22:55:49,861: ### Device cuda:0 will be used for training
# 2026-01-31 22:55:49,869: Loading basin data into xarray data set.
#   0%|          | 0/11 [00:00<?, ?it/s]
# 100%|██████████| 11/11 [00:00<00:00, 78.15it/s]
# 2026-01-31 22:55:50,022: Calculating target variable stds per basin
# 100%|██████████| 11/11 [00:00<00:00, 1471.69it/s]
# 2026-01-31 22:55:50,035: Create lookup table and convert to pytorch tensor
# 100%|██████████| 11/11 [00:00<00:00, 41.86it/s]
# 2026-01-31 22:55:50,326: Validation set to validate every 1 epoch(s), but 'validate_n_random_basins' not set or set to zero. Will validate on the entire validation set.
# # Epoch 1: 100%|██████████| 132/132 [00:07<00:00, 17.20it/s, Loss: 0.0602]
# 2026-01-31 22:55:58,008: Epoch 1 average loss: avg_loss: 0.06639, avg_total_loss: 0.06639
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.37it/s]
# 2026-01-31 22:56:02,659: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch001/validation_metrics.csv
# 2026-01-31 22:56:02,662: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch001/validation_results.p
# 2026-01-31 22:56:02,664: Epoch 1 average validation loss: 0.06119 -- Median validation metrics: avg_loss: 0.06119, NSE: 0.04702, KGE: -0.16047, Alpha-NSE: 0.12663, Beta-NSE: 0.11777, Pearson-r: 0.34095, RMSE: 2.59769, MSE: 6.74798, Beta-KGE: 1.24162
# # Epoch 2: 100%|██████████| 132/132 [00:07<00:00, 18.33it/s, Loss: 0.0498]
# 2026-01-31 22:56:09,871: Epoch 2 average loss: avg_loss: 0.05149, avg_total_loss: 0.05149
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.64it/s]
# 2026-01-31 22:56:14,048: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch002/validation_metrics.csv
# 2026-01-31 22:56:14,052: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch002/validation_results.p
# 2026-01-31 22:56:14,054: Epoch 2 average validation loss: 0.04218 -- Median validation metrics: avg_loss: 0.04218, NSE: 0.33407, KGE: 0.23680, Alpha-NSE: 0.55262, Beta-NSE: 0.12350, Pearson-r: 0.69979, RMSE: 2.17813, MSE: 4.74424, Beta-KGE: 1.22516
# # Epoch 3: 100%|██████████| 132/132 [00:07<00:00, 18.47it/s, Loss: 0.0994]
# 2026-01-31 22:56:21,206: Epoch 3 average loss: avg_loss: 0.03832, avg_total_loss: 0.03832
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.76it/s]
# 2026-01-31 22:56:25,205: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch003/validation_metrics.csv
# 2026-01-31 22:56:25,208: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch003/validation_results.p
# 2026-01-31 22:56:25,211: Epoch 3 average validation loss: 0.03455 -- Median validation metrics: avg_loss: 0.03455, NSE: 0.52320, KGE: 0.43413, Alpha-NSE: 0.67353, Beta-NSE: 0.03217, Pearson-r: 0.75728, RMSE: 1.60870, MSE: 2.58790, Beta-KGE: 1.05416
# # Epoch 4: 100%|██████████| 132/132 [00:07<00:00, 18.41it/s, Loss: 0.0360]
# 2026-01-31 22:56:32,385: Epoch 4 average loss: avg_loss: 0.03239, avg_total_loss: 0.03239
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.75it/s]
# 2026-01-31 22:56:36,393: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch004/validation_metrics.csv
# 2026-01-31 22:56:36,396: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch004/validation_results.p
# 2026-01-31 22:56:36,398: Epoch 4 average validation loss: 0.03091 -- Median validation metrics: avg_loss: 0.03091, NSE: 0.53824, KGE: 0.55962, Alpha-NSE: 0.72777, Beta-NSE: -0.02992, Pearson-r: 0.77081, RMSE: 1.68389, MSE: 2.83549, Beta-KGE: 0.95159
# # Epoch 5: 100%|██████████| 132/132 [00:07<00:00, 18.37it/s, Loss: 0.0209]
# 2026-01-31 22:56:43,588: Epoch 5 average loss: avg_loss: 0.02852, avg_total_loss: 0.02852
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.65it/s]
# 2026-01-31 22:56:47,758: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch005/validation_metrics.csv
# 2026-01-31 22:56:47,762: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch005/validation_results.p
# 2026-01-31 22:56:47,764: Epoch 5 average validation loss: 0.03320 -- Median validation metrics: avg_loss: 0.03320, NSE: 0.61020, KGE: 0.55144, Alpha-NSE: 0.83374, Beta-NSE: 0.09346, Pearson-r: 0.79557, RMSE: 1.52194, MSE: 2.31630, Beta-KGE: 1.29770
# # Epoch 6: 100%|██████████| 132/132 [00:07<00:00, 18.27it/s, Loss: 0.0143]
# 2026-01-31 22:56:54,993: Epoch 6 average loss: avg_loss: 0.02541, avg_total_loss: 0.02541
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.76it/s]
# 2026-01-31 22:56:58,983: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch006/validation_metrics.csv
# 2026-01-31 22:56:58,986: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch006/validation_results.p
# 2026-01-31 22:56:58,989: Epoch 6 average validation loss: 0.02582 -- Median validation metrics: avg_loss: 0.02582, NSE: 0.59405, KGE: 0.64027, Alpha-NSE: 0.85535, Beta-NSE: 0.13916, Pearson-r: 0.82360, RMSE: 1.46306, MSE: 2.14053, Beta-KGE: 1.25372
# # Epoch 7: 100%|██████████| 132/132 [00:07<00:00, 17.82it/s, Loss: 0.0225]
# 2026-01-31 22:57:06,398: Epoch 7 average loss: avg_loss: 0.02306, avg_total_loss: 0.02306
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.76it/s]
# 2026-01-31 22:57:10,401: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch007/validation_metrics.csv
# 2026-01-31 22:57:10,405: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch007/validation_results.p
# 2026-01-31 22:57:10,407: Epoch 7 average validation loss: 0.02674 -- Median validation metrics: avg_loss: 0.02674, NSE: 0.61610, KGE: 0.63741, Alpha-NSE: 0.95194, Beta-NSE: 0.11711, Pearson-r: 0.83448, RMSE: 1.51917, MSE: 2.30789, Beta-KGE: 1.18724
# # Epoch 8: 100%|██████████| 132/132 [00:07<00:00, 18.31it/s, Loss: 0.0060]
# 2026-01-31 22:57:17,618: Epoch 8 average loss: avg_loss: 0.02188, avg_total_loss: 0.02188
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.76it/s]
# 2026-01-31 22:57:21,622: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch008/validation_metrics.csv
# 2026-01-31 22:57:21,626: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch008/validation_results.p
# 2026-01-31 22:57:21,628: Epoch 8 average validation loss: 0.02484 -- Median validation metrics: avg_loss: 0.02484, NSE: 0.68275, KGE: 0.61547, Alpha-NSE: 0.89778, Beta-NSE: 0.06015, Pearson-r: 0.83048, RMSE: 1.34730, MSE: 1.81523, Beta-KGE: 1.09733
# # Epoch 9: 100%|██████████| 132/132 [00:07<00:00, 17.43it/s, Loss: 0.0134]
# 2026-01-31 22:57:29,207: Epoch 9 average loss: avg_loss: 0.02117, avg_total_loss: 0.02117
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.64it/s]
# 2026-01-31 22:57:33,391: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch009/validation_metrics.csv
# 2026-01-31 22:57:33,394: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch009/validation_results.p
# 2026-01-31 22:57:33,396: Epoch 9 average validation loss: 0.02566 -- Median validation metrics: avg_loss: 0.02566, NSE: 0.66262, KGE: 0.65425, Alpha-NSE: 0.96130, Beta-NSE: 0.08847, Pearson-r: 0.82836, RMSE: 1.34193, MSE: 1.80079, Beta-KGE: 1.16185
# # Epoch 10: 100%|██████████| 132/132 [00:07<00:00, 18.25it/s, Loss: 0.0058]
# 2026-01-31 22:57:40,633: Epoch 10 average loss: avg_loss: 0.01968, avg_total_loss: 0.01968
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-01-31 22:57:44,650: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch010/validation_metrics.csv
# 2026-01-31 22:57:44,653: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch010/validation_results.p
# 2026-01-31 22:57:44,656: Epoch 10 average validation loss: 0.02611 -- Median validation metrics: avg_loss: 0.02611, NSE: 0.68743, KGE: 0.65115, Alpha-NSE: 0.95412, Beta-NSE: 0.06405, Pearson-r: 0.83508, RMSE: 1.35504, MSE: 1.83614, Beta-KGE: 1.10364
# # Epoch 11: 100%|██████████| 132/132 [00:07<00:00, 18.16it/s, Loss: 0.0116]
# 2026-01-31 22:57:51,928: Epoch 11 average loss: avg_loss: 0.01937, avg_total_loss: 0.01937
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-01-31 22:57:55,949: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch011/validation_metrics.csv
# 2026-01-31 22:57:55,952: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch011/validation_results.p
# 2026-01-31 22:57:55,955: Epoch 11 average validation loss: 0.02399 -- Median validation metrics: avg_loss: 0.02399, NSE: 0.66428, KGE: 0.58350, Alpha-NSE: 0.88343, Beta-NSE: 0.06927, Pearson-r: 0.82882, RMSE: 1.27930, MSE: 1.63662, Beta-KGE: 1.18937
# # Epoch 12: 100%|██████████| 132/132 [00:07<00:00, 18.06it/s, Loss: 0.0072]
# 2026-01-31 22:58:03,266: Epoch 12 average loss: avg_loss: 0.01894, avg_total_loss: 0.01894
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.61it/s]
# 2026-01-31 22:58:07,487: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch012/validation_metrics.csv
# 2026-01-31 22:58:07,490: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch012/validation_results.p
# 2026-01-31 22:58:07,493: Epoch 12 average validation loss: 0.02609 -- Median validation metrics: avg_loss: 0.02609, NSE: 0.63624, KGE: 0.60562, Alpha-NSE: 0.99488, Beta-NSE: 0.09580, Pearson-r: 0.83742, RMSE: 1.38895, MSE: 1.92918, Beta-KGE: 1.17874
# # Epoch 13: 100%|██████████| 132/132 [00:07<00:00, 17.67it/s, Loss: 0.0096]
# 2026-01-31 22:58:14,969: Epoch 13 average loss: avg_loss: 0.01829, avg_total_loss: 0.01829
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-01-31 22:58:18,988: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch013/validation_metrics.csv
# 2026-01-31 22:58:18,991: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch013/validation_results.p
# 2026-01-31 22:58:18,994: Epoch 13 average validation loss: 0.02313 -- Median validation metrics: avg_loss: 0.02313, NSE: 0.68147, KGE: 0.73875, Alpha-NSE: 0.88251, Beta-NSE: 0.05096, Pearson-r: 0.83104, RMSE: 1.26577, MSE: 1.60218, Beta-KGE: 1.08341
# # Epoch 14: 100%|██████████| 132/132 [00:07<00:00, 17.87it/s, Loss: 0.0116]
# 2026-01-31 22:58:26,382: Epoch 14 average loss: avg_loss: 0.01755, avg_total_loss: 0.01755
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-01-31 22:58:30,397: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch014/validation_metrics.csv
# 2026-01-31 22:58:30,401: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch014/validation_results.p
# 2026-01-31 22:58:30,403: Epoch 14 average validation loss: 0.02575 -- Median validation metrics: avg_loss: 0.02575, NSE: 0.65862, KGE: 0.67110, Alpha-NSE: 0.90036, Beta-NSE: 0.11481, Pearson-r: 0.83768, RMSE: 1.30004, MSE: 1.69011, Beta-KGE: 1.22632
# # Epoch 15: 100%|██████████| 132/132 [00:07<00:00, 17.81it/s, Loss: 0.0130]
# 2026-01-31 22:58:37,818: Epoch 15 average loss: avg_loss: 0.01680, avg_total_loss: 0.01680
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.62it/s]
# 2026-01-31 22:58:42,030: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch015/validation_metrics.csv
# 2026-01-31 22:58:42,033: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch015/validation_results.p
# 2026-01-31 22:58:42,036: Epoch 15 average validation loss: 0.03023 -- Median validation metrics: avg_loss: 0.03023, NSE: 0.58975, KGE: 0.52689, Alpha-NSE: 1.13257, Beta-NSE: 0.19091, Pearson-r: 0.84144, RMSE: 1.63384, MSE: 2.66943, Beta-KGE: 1.36639
# # Epoch 16: 100%|██████████| 132/132 [00:07<00:00, 17.60it/s, Loss: 0.0169]
# 2026-01-31 22:58:49,539: Epoch 16 average loss: avg_loss: 0.01669, avg_total_loss: 0.01669
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-01-31 22:58:53,570: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch016/validation_metrics.csv
# 2026-01-31 22:58:53,573: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch016/validation_results.p
# 2026-01-31 22:58:53,576: Epoch 16 average validation loss: 0.02886 -- Median validation metrics: avg_loss: 0.02886, NSE: 0.62944, KGE: 0.59089, Alpha-NSE: 1.03643, Beta-NSE: 0.13162, Pearson-r: 0.81428, RMSE: 1.46514, MSE: 2.14663, Beta-KGE: 1.33406
# # Epoch 17: 100%|██████████| 132/132 [00:07<00:00, 17.87it/s, Loss: 0.0071]
# 2026-01-31 22:59:00,964: Epoch 17 average loss: avg_loss: 0.01601, avg_total_loss: 0.01601
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-01-31 22:59:04,991: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch017/validation_metrics.csv
# 2026-01-31 22:59:04,994: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch017/validation_results.p
# 2026-01-31 22:59:04,997: Epoch 17 average validation loss: 0.02630 -- Median validation metrics: avg_loss: 0.02630, NSE: 0.63981, KGE: 0.64045, Alpha-NSE: 1.03790, Beta-NSE: 0.09739, Pearson-r: 0.83718, RMSE: 1.39935, MSE: 1.95818, Beta-KGE: 1.23762
# # Epoch 18: 100%|██████████| 132/132 [00:07<00:00, 17.82it/s, Loss: 0.0047]
# 2026-01-31 22:59:12,408: Epoch 18 average loss: avg_loss: 0.01557, avg_total_loss: 0.01557
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.66it/s]
# 2026-01-31 22:59:16,558: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch018/validation_metrics.csv
# 2026-01-31 22:59:16,561: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch018/validation_results.p
# 2026-01-31 22:59:16,564: Epoch 18 average validation loss: 0.02860 -- Median validation metrics: avg_loss: 0.02860, NSE: 0.61032, KGE: 0.55178, Alpha-NSE: 1.07215, Beta-NSE: 0.12929, Pearson-r: 0.84011, RMSE: 1.54690, MSE: 2.39291, Beta-KGE: 1.25458
# # Epoch 19: 100%|██████████| 132/132 [00:07<00:00, 16.98it/s, Loss: 0.0156]
# 2026-01-31 22:59:24,341: Epoch 19 average loss: avg_loss: 0.01511, avg_total_loss: 0.01511
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.62it/s]
# 2026-01-31 22:59:28,554: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch019/validation_metrics.csv
# 2026-01-31 22:59:28,557: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch019/validation_results.p
# 2026-01-31 22:59:28,560: Epoch 19 average validation loss: 0.02580 -- Median validation metrics: avg_loss: 0.02580, NSE: 0.64213, KGE: 0.66041, Alpha-NSE: 1.10347, Beta-NSE: 0.06778, Pearson-r: 0.84613, RMSE: 1.42253, MSE: 2.02359, Beta-KGE: 1.10435
# # Epoch 20: 100%|██████████| 132/132 [00:07<00:00, 17.78it/s, Loss: 0.0099]
# 2026-01-31 22:59:35,986: Epoch 20 average loss: avg_loss: 0.01461, avg_total_loss: 0.01461
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.73it/s]
# 2026-01-31 22:59:40,020: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch020/validation_metrics.csv
# 2026-01-31 22:59:40,023: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch020/validation_results.p
# 2026-01-31 22:59:40,026: Epoch 20 average validation loss: 0.02367 -- Median validation metrics: avg_loss: 0.02367, NSE: 0.69714, KGE: 0.78423, Alpha-NSE: 1.03085, Beta-NSE: 0.01174, Pearson-r: 0.85064, RMSE: 1.32669, MSE: 1.76011, Beta-KGE: 1.01899
# # Epoch 21: 100%|██████████| 132/132 [00:07<00:00, 17.81it/s, Loss: 0.0266]
# 2026-01-31 22:59:47,442: Epoch 21 average loss: avg_loss: 0.01468, avg_total_loss: 0.01468
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-01-31 22:59:51,475: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch021/validation_metrics.csv
# 2026-01-31 22:59:51,478: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch021/validation_results.p
# 2026-01-31 22:59:51,481: Epoch 21 average validation loss: 0.03094 -- Median validation metrics: avg_loss: 0.03094, NSE: 0.67285, KGE: 0.42829, Alpha-NSE: 1.05523, Beta-NSE: 0.19645, Pearson-r: 0.84647, RMSE: 1.39020, MSE: 1.93266, Beta-KGE: 1.47012
# # Epoch 22: 100%|██████████| 132/132 [00:07<00:00, 17.89it/s, Loss: 0.0049]
# 2026-01-31 22:59:58,860: Epoch 22 average loss: avg_loss: 0.01457, avg_total_loss: 0.01457
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.62it/s]
# 2026-01-31 23:00:03,070: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch022/validation_metrics.csv
# 2026-01-31 23:00:03,074: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch022/validation_results.p
# 2026-01-31 23:00:03,076: Epoch 22 average validation loss: 0.02722 -- Median validation metrics: avg_loss: 0.02722, NSE: 0.62148, KGE: 0.67837, Alpha-NSE: 1.11778, Beta-NSE: 0.08535, Pearson-r: 0.84092, RMSE: 1.58042, MSE: 2.49773, Beta-KGE: 1.19903
# # Epoch 23: 100%|██████████| 132/132 [00:07<00:00, 17.93it/s, Loss: 0.0061]
# 2026-01-31 23:00:10,442: Epoch 23 average loss: avg_loss: 0.01339, avg_total_loss: 0.01339
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-01-31 23:00:14,473: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch023/validation_metrics.csv
# 2026-01-31 23:00:14,477: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch023/validation_results.p
# 2026-01-31 23:00:14,480: Epoch 23 average validation loss: 0.02762 -- Median validation metrics: avg_loss: 0.02762, NSE: 0.59276, KGE: 0.63635, Alpha-NSE: 1.12681, Beta-NSE: 0.05297, Pearson-r: 0.83913, RMSE: 1.52173, MSE: 2.31567, Beta-KGE: 1.08572
# # Epoch 24: 100%|██████████| 132/132 [00:07<00:00, 17.57it/s, Loss: 0.0145]
# 2026-01-31 23:00:21,994: Epoch 24 average loss: avg_loss: 0.01469, avg_total_loss: 0.01469
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.70it/s]
# 2026-01-31 23:00:26,086: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch024/validation_metrics.csv
# 2026-01-31 23:00:26,090: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch024/validation_results.p
# 2026-01-31 23:00:26,092: Epoch 24 average validation loss: 0.02980 -- Median validation metrics: avg_loss: 0.02980, NSE: 0.58838, KGE: 0.51919, Alpha-NSE: 1.13329, Beta-NSE: 0.14743, Pearson-r: 0.83810, RMSE: 1.58985, MSE: 2.52761, Beta-KGE: 1.27216
# # Epoch 25: 100%|██████████| 132/132 [00:07<00:00, 17.88it/s, Loss: 0.0040]
# 2026-01-31 23:00:33,476: Epoch 25 average loss: avg_loss: 0.01381, avg_total_loss: 0.01381
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.62it/s]
# 2026-01-31 23:00:37,690: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch025/validation_metrics.csv
# 2026-01-31 23:00:37,693: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch025/validation_results.p
# 2026-01-31 23:00:37,696: Epoch 25 average validation loss: 0.02339 -- Median validation metrics: avg_loss: 0.02339, NSE: 0.64947, KGE: 0.75127, Alpha-NSE: 0.96218, Beta-NSE: 0.00797, Pearson-r: 0.82652, RMSE: 1.30812, MSE: 1.71118, Beta-KGE: 1.01290
# # Epoch 26: 100%|██████████| 132/132 [00:07<00:00, 17.79it/s, Loss: 0.0047]
# 2026-01-31 23:00:45,120: Epoch 26 average loss: avg_loss: 0.01339, avg_total_loss: 0.01339
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-01-31 23:00:49,136: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch026/validation_metrics.csv
# 2026-01-31 23:00:49,139: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch026/validation_results.p
# 2026-01-31 23:00:49,142: Epoch 26 average validation loss: 0.02922 -- Median validation metrics: avg_loss: 0.02922, NSE: 0.62642, KGE: 0.56782, Alpha-NSE: 1.20448, Beta-NSE: 0.04876, Pearson-r: 0.82677, RMSE: 1.51461, MSE: 2.29405, Beta-KGE: 1.08941
# # Epoch 27: 100%|██████████| 132/132 [00:07<00:00, 17.88it/s, Loss: 0.0344]
# 2026-01-31 23:00:56,526: Epoch 27 average loss: avg_loss: 0.01283, avg_total_loss: 0.01283
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-01-31 23:01:00,548: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch027/validation_metrics.csv
# 2026-01-31 23:01:00,551: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch027/validation_results.p
# 2026-01-31 23:01:00,554: Epoch 27 average validation loss: 0.02656 -- Median validation metrics: avg_loss: 0.02656, NSE: 0.65594, KGE: 0.56583, Alpha-NSE: 1.08835, Beta-NSE: 0.12081, Pearson-r: 0.83408, RMSE: 1.45354, MSE: 2.11278, Beta-KGE: 1.18464
# # Epoch 28: 100%|██████████| 132/132 [00:07<00:00, 17.72it/s, Loss: 0.0081]
# 2026-01-31 23:01:08,007: Epoch 28 average loss: avg_loss: 0.01261, avg_total_loss: 0.01261
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.74it/s]
# 2026-01-31 23:01:12,034: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch028/validation_metrics.csv
# 2026-01-31 23:01:12,038: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch028/validation_results.p
# 2026-01-31 23:01:12,040: Epoch 28 average validation loss: 0.02643 -- Median validation metrics: avg_loss: 0.02643, NSE: 0.66275, KGE: 0.62890, Alpha-NSE: 1.08092, Beta-NSE: 0.10122, Pearson-r: 0.84645, RMSE: 1.43388, MSE: 2.05602, Beta-KGE: 1.15469
# # Epoch 29: 100%|██████████| 132/132 [00:07<00:00, 17.33it/s, Loss: 0.0056]
# 2026-01-31 23:01:19,660: Epoch 29 average loss: avg_loss: 0.01179, avg_total_loss: 0.01179
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.61it/s]
# 2026-01-31 23:01:23,879: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch029/validation_metrics.csv
# 2026-01-31 23:01:23,882: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch029/validation_results.p
# 2026-01-31 23:01:23,885: Epoch 29 average validation loss: 0.02681 -- Median validation metrics: avg_loss: 0.02681, NSE: 0.64821, KGE: 0.65998, Alpha-NSE: 1.10175, Beta-NSE: 0.06286, Pearson-r: 0.83826, RMSE: 1.46976, MSE: 2.16021, Beta-KGE: 1.11400
# # Epoch 30: 100%|██████████| 132/132 [00:07<00:00, 17.59it/s, Loss: 0.0059]
# 2026-01-31 23:01:31,391: Epoch 30 average loss: avg_loss: 0.01161, avg_total_loss: 0.01161
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.73it/s]
# 2026-01-31 23:01:35,430: Stored metrics at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch030/validation_metrics.csv
# 2026-01-31 23:01:35,433: Stored results at /home/azureuser/sky_workdir/MSWEP/runs/corrected_new_correction_mswep_and_gauge_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_3101_225549/validation/model_epoch030/validation_results.p
# 2026-01-31 23:01:35,436: Epoch 30 average validation loss: 0.02740 -- Median validation metrics: avg_loss: 0.02740, NSE: 0.65750, KGE: 0.57156, Alpha-NSE: 1.05050, Beta-NSE: 0.08640, Pearson-r: 0.83827, RMSE: 1.45024, MSE: 2.10321, Beta-KGE: 1.21533
