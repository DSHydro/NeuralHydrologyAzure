nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014146.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014147.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014148.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014149.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014150.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014151.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014152.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014153.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014154.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014155.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014156.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014157.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014158.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014159.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014160.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014161.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014162.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014163.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014164.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014165.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014166.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014167.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014168.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014169.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014170.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014171.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014172.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014173.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014174.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014175.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014176.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014177.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014178.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014179.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014180.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014181.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014182.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014183.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014184.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014185.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014186.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014187.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014188.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014189.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014190.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014191.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014192.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014193.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014194.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014195.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014196.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014197.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014198.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014199.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014200.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014201.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014202.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014203.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014204.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014205.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014206.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014207.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014208.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014209.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014210.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014211.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014212.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014213.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014214.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014215.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014216.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014217.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014218.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014219.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014220.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014221.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014222.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014223.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014224.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014225.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014226.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014227.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014228.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014229.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014230.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014231.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014232.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014233.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014234.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014235.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014236.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014237.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014238.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014239.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014240.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014241.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014242.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014243.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014244.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014245.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014246.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014247.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014248.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014249.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014250.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014251.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014252.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014253.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014254.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014255.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014256.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014257.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014258.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014259.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014260.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014261.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014262.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014263.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014264.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014265.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014266.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014267.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014268.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014269.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014270.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014271.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014272.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014273.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014274.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014275.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014276.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014277.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014278.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014279.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014280.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014281.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014282.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014283.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014284.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014285.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014286.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014287.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014288.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014289.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014290.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014291.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014292.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014293.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014294.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014295.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014296.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014297.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014298.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014299.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014300.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014301.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014302.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014303.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014304.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014305.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014306.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014307.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014308.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014309.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014310.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014311.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014312.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014313.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014314.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014315.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014316.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014317.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014318.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014319.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014320.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014321.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014322.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014323.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014324.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014325.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014326.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014327.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014328.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014329.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014330.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014331.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014332.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014333.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014334.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014335.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014336.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014337.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014338.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014339.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014340.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014341.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014342.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014343.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014344.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014345.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014346.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014347.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014348.nc: Operation not supported
# getfattr: /inputs/MSWEP_V280/Past/Daily/2014349.nc: Operation not supported

# %%
path_data = '/inputs/MSWEP_V280/Past/Daily'
path_shapefiles = Path('./shapefiles')

# %%
# List all files
all_files = sorted(glob.glob(f'{path_data}/*.nc'))

# %%
# gdf = gpd.read_file(path_shapefiles)
# gdf

# %%
# # Reproject if needed
# if gdf.crs != "EPSG:4326":
#     gdf = gdf.to_crs("EPSG:4326")

# %%
# Filter by year 1989–2008
# files = [f for f in all_files if 1989 <= int(os.path.basename(f)[:4]) <= 2008]
files = [f for f in all_files if 2009 <= int(os.path.basename(f)[:4]) <= 2019]

print(f"Total files to process: {len(files)}")
# Out:
# Total files to process: 4017

# %%
basins_mapping = {
    'paso_mazangano': 'CAMELS_UY_10',
    'picada_de_coelho': 'CAMELS_UY_7',
    'sarandi_del_yi': 'CAMELS_UY_12',
    'paso_de_las_toscas': 'CAMELS_UY_8',
    'paso_de_las_piedras_rn': 'CAMELS_UY_15',
    'paso_del_borracho': 'CAMELS_UY_6',
    'bequelo': 'CAMELS_UY_16',
    'paso_de_las_piedras': 'CAMELS_UY_2',
    'paso_baltasar': 'CAMELS_UY_5',
    'fraile_muerto': 'CAMELS_UY_11',
    'paso_de_los_mellizos': 'CAMELS_UY_14',
    'paso_manuel_diaz': 'CAMELS_UY_3',
    'paso_aguiar': 'CAMELS_UY_9',
    'paso_de_la_compania': 'CAMELS_UY_1',
    'tacuarembo': 'CAMELS_UY_4',
    'durazno': 'CAMELS_UY_13'
}

# %%
shapefiles = os.listdir(path_shapefiles)
shapefiles=shapefiles[1:]
shapefiles
# Out:
# ['paso_de_las_piedras.zip',
#  'paso_de_la_compania.zip',
#  'fraile_muerto.zip',
#  'paso_aguiar.zip',
#  'mercedes.zip',
#  'bequelo.zip',
#  'sarandi_del_yi.zip',
#  'paso_manuel_diaz.zip',
#  'paso_de_los_mellizos.zip',
#  'paso_de_las_toscas.zip',
#  'paso_del_borracho.zip',
#  'picada_de_coelho.zip',
#  'paso_mazangano.zip',
#  'paso_de_las_piedras_rn.zip',
#  'paso_baltasar.zip',
#  'tacuarembo.zip']

# %%
# for shapefile in os.listdir(path_shapefiles):
for shapefile in shapefiles:
    print("Processing shapefile:", shapefile)
    results = []

    gdf = gpd.read_file(path_shapefiles / shapefile)

    # Reproject if needed
    if gdf.crs != "EPSG:4326":
        gdf = gdf.to_crs("EPSG:4326")

    # for i, f in enumerate(files, start=1):
    for f in tqdm(files, desc=f"Files for {shapefile}", file=sys.stdout):
        # print("Opening:", f)
        ds = xr.open_dataset(f)
        da = ds["precipitation"]

        # Rename coordinates and assign CRS
        da = da.rename({"lat": "y", "lon": "x"})
        da = da.rio.write_crs("EPSG:4326")

        # Clip to basin
        da_clip = da.rio.clip(
            gdf.geometry,
            gdf.crs,
            drop=True,
            all_touched=True
        )

        # Compute basin mean
        mean_val = da_clip.mean(dim=("y", "x"), skipna=True).values.item()

        # Extract date
        date = pd.to_datetime(ds.time.values[0])

        results.append({"date": date, "precip_mm": mean_val})

        ds.close()

        # print(f"Processed file {i}/{len(files)}: {f.split('/')[-1]} | Basin mean: {mean_val:.2f} mm")
    
    df_results = pd.DataFrame(results)
    df_results = df_results.sort_values("date").set_index("date")

    basin_key = os.path.splitext(shapefile)[0].lower().replace(" ", "_")
    basin = basins_mapping.get(basin_key, basin_key)
    
    out_path = Path(f'./precip_timeseries/{basin}_precip_2.csv')
    df_results.to_csv(out_path)
# Out:
# Processing shapefile: paso_de_las_piedras.zip
# Files for paso_de_las_piedras.zip:   0%|          | 0/4017 [00:00<?, ?it/s]
# Files for paso_de_las_piedras.zip: 100%|██████████| 4017/4017 [43:36<00:00,  1.54it/s]
# Processing shapefile: paso_de_la_compania.zip
# Files for paso_de_la_compania.zip:  54%|█████▍    | 2175/4017 [22:47<13:42,  2.24it/s]
