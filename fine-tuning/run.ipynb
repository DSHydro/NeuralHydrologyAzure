# %%
from pathlib import Path
import sys
import pandas as pd
import torch
import matplotlib.pyplot as plt
import xarray as xr
import yaml
import geopandas as gpd
import contextily as cx
from adjustText import adjust_text

from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.nh_run import continue_run
from neuralhydrology.utils.config import Config
from neuralhydrology.evaluation import get_tester, metrics

# %%
# -------- Paths ---------
CONFIG_PATH = Path("./run.yml")
RUNS_DIR = Path("runs")
PLOTS_DIR = Path("./evaluation_plots")
RUNS_DIR = Path("runs")
PLOTS_DIR = Path("evaluation_plots")
# ATTRIBUTES_FILE= Path('/inputs/data_updated/attributes/attributes_other.csv')

# %%
# by default we assume that you have at least one CUDA-capable NVIDIA GPU or MacOS with Metal support
if torch.cuda.is_available() or torch.backends.mps.is_available():
    start_run(config_file=Path("run.yml"))

# fall back to CPU-only mode
else:
    start_run(config_file=Path("run.yml"), gpu=-1)
# Out:
# 2026-03-24 17:45:07,676: Logging to /home/azureuser/sky_workdir/fine-tuning/runs/531_us_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_2403_174507/output.log initialized.
# 2026-03-24 17:45:07,677: ### Folder structure created at /home/azureuser/sky_workdir/fine-tuning/runs/531_us_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_2403_174507
# 2026-03-24 17:45:07,677: ### Run configurations for 531_us_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111
# 2026-03-24 17:45:07,678: experiment_name: 531_us_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111
# 2026-03-24 17:45:07,679: run_dir: /home/azureuser/sky_workdir/fine-tuning/runs/531_us_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_2403_174507
# 2026-03-24 17:45:07,679: train_basin_file: 531_basin_list.txt
# 2026-03-24 17:45:07,679: validation_basin_file: 531_basin_list.txt
# 2026-03-24 17:45:07,680: test_basin_file: 531_basin_list.txt
# 2026-03-24 17:45:07,680: train_start_date: 1999-10-01 00:00:00
# 2026-03-24 17:45:07,681: train_end_date: 2008-09-30 00:00:00
# 2026-03-24 17:45:07,681: validation_start_date: 1989-10-01 00:00:00
# 2026-03-24 17:45:07,682: validation_end_date: 1999-09-30 00:00:00
# 2026-03-24 17:45:07,683: seed: 111
# 2026-03-24 17:45:07,683: device: cuda:0
# 2026-03-24 17:45:07,684: validate_every: 1
# 2026-03-24 17:45:07,684: metrics: ['NSE', 'KGE', 'Alpha-NSE', 'Beta-NSE', 'Pearson-r', 'RMSE', 'MSE', 'Beta-KGE']
# 2026-03-24 17:45:07,685: model: cudalstm
# 2026-03-24 17:45:07,685: head: regression
# 2026-03-24 17:45:07,686: hidden_size: 256
# 2026-03-24 17:45:07,686: initial_forget_bias: 5
# 2026-03-24 17:45:07,686: output_dropout: 0.4
# 2026-03-24 17:45:07,687: output_activation: linear
# 2026-03-24 17:45:07,687: optimizer: Adam
# 2026-03-24 17:45:07,688: loss: NSE
# 2026-03-24 17:45:07,688: learning_rate: {0: 0.001}
# 2026-03-24 17:45:07,689: batch_size: 256
# 2026-03-24 17:45:07,689: epochs: 30
# 2026-03-24 17:45:07,690: clip_gradient_norm: 1
# 2026-03-24 17:45:07,690: predict_last_n: 1
# 2026-03-24 17:45:07,691: seq_length: 270
# 2026-03-24 17:45:07,691: num_workers: 4
# 2026-03-24 17:45:07,691: log_interval: 5
# 2026-03-24 17:45:07,692: log_tensorboard: True
# 2026-03-24 17:45:07,692: save_weights_every: 1
# 2026-03-24 17:45:07,693: save_validation_results: True
# 2026-03-24 17:45:07,693: data_dir: /inputs/data_updated_2
# 2026-03-24 17:45:07,694: dataset: generic
# 2026-03-24 17:45:07,694: dynamic_inputs: ['total_precipitation_sum', 'temperature_2m_max', 'temperature_2m_min', 'surface_net_solar_radiation_mean']
# 2026-03-24 17:45:07,695: target_variables: ['streamflow']
# 2026-03-24 17:45:07,695: static_attributes: ['ele_mt_sav', 'slp_dg_sav', 'area', 'snd_pc_sav', 'slt_pc_sav', 'cly_pc_sav', 'pet_mean_FAO_PM', 'aridity_FAO_PM', 'frac_snow', 'p_mean', 'high_prec_dur', 'low_prec_dur']
# 2026-03-24 17:45:07,696: number_of_basins: 531
# 2026-03-24 17:45:07,696: train_dir: /home/azureuser/sky_workdir/fine-tuning/runs/531_us_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_2403_174507/train_data
# 2026-03-24 17:45:07,697: img_log_dir: /home/azureuser/sky_workdir/fine-tuning/runs/531_us_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_2403_174507/img_log
# 2026-03-24 17:45:07,698: ### Device cuda:0 will be used for training
# 2026-03-24 17:45:08,413: Loading basin data into xarray data set.
#   3%|▎         | 17/531 [00:12<06:05,  1.41it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # by default we assume that you have at least one CUDA-capable NVIDIA GPU or MacOS with Metal support
#       2 if torch.cuda.is_available() or torch.backends.mps.is_available():
# ----> 3     start_run(config_file=Path("run.yml"))
#       5 # fall back to CPU-only mode
#       6 else:
#       7     start_run(config_file=Path("run.yml"), gpu=-1)
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 start_training(config)
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/training/train.py:19, in start_training(cfg)
#      17 else:
#      18     raise ValueError(f"Unknown head {cfg.head}.")
# ---> 19 trainer.initialize_training()
#      20 trainer.train_and_validate()
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/training/basetrainer.py:147, in BaseTrainer.initialize_training(self)
#     144     self._scaler = load_scaler(self.cfg.base_run_dir)
#     146 # Initialize dataset before the model is loaded.
# --> 147 ds = self._get_dataset()
#     148 if len(ds) == 0:
#     149     raise ValueError("Dataset contains no samples.")
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/training/basetrainer.py:80, in BaseTrainer._get_dataset(self)
#      79 def _get_dataset(self) -> BaseDataset:
# ---> 80     return get_dataset(cfg=self.cfg, period="train", is_train=True, scaler=self._scaler)
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/datasetzoo/__init__.py:83, in get_dataset(cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      80 else:
#      81     raise NotImplementedError(f"No dataset class implemented for dataset {cfg.dataset}")
# ---> 83 ds = Dataset(cfg=cfg,
#      84              is_train=is_train,
#      85              period=period,
#      86              basin=basin,
#      87              additional_features=additional_features,
#      88              id_to_int=id_to_int,
#      89              scaler=scaler)
#      90 return ds
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/datasetzoo/genericdataset.py:61, in GenericDataset.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      53 def __init__(self,
#      54              cfg: Config,
#      55              is_train: bool,
#    (...)
#      59              id_to_int: Dict[str, int] = {},
#      60              scaler: Dict[str, Union[pd.Series, xarray.DataArray]] = {}):
# ---> 61     super(GenericDataset, self).__init__(cfg=cfg,
#      62                                          is_train=is_train,
#      63                                          period=period,
#      64                                          basin=basin,
#      65                                          additional_features=additional_features,
#      66                                          id_to_int=id_to_int,
#      67                                          scaler=scaler)
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/datasetzoo/basedataset.py:142, in BaseDataset.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#     139         self._create_id_to_int()
#     141 # load and preprocess data
# --> 142 self._load_data()
#     144 if self.is_train:
#     145     self._dump_scaler()
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/datasetzoo/basedataset.py:747, in BaseDataset._load_data(self)
#     743 def _load_data(self):
#     744     # load attributes first to sanity-check those features before doing the compute expensive time series loading
#     745     self._load_combined_attributes()
# --> 747     xr = self._load_or_create_xarray_dataset()
#     749     if self.cfg.loss.lower() in ['nse', 'weightednse']:
#     750         # get the std of the discharge for each basin, which is needed for the (weighted) NSE loss.
#     751         self._calculate_per_basin_std(xr)
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/datasetzoo/basedataset.py:470, in BaseDataset._load_or_create_xarray_dataset(self)
#     467 df_duplicated = df[df.index.duplicated(keep=False)]
#     469 filtered_duplicates = []
# --> 470 for _, grp in df_duplicated.groupby('date'):
#     471     mask = ~grp[self.cfg.target_variables].isna().any(axis=1)
#     472     if not mask.any():
#     473         # In case all duplicates have a NaN value for the targets, pick the first. This can happen, if
#     474         # the day itself has a missing observation.
#
# File ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1203, in BaseGroupBy.__iter__(self)
#    1201 keys = self.keys
#    1202 level = self.level
# -> 1203 result = self._grouper.get_iterator(self._selected_obj, axis=self.axis)
#    1204 # error: Argument 1 to "len" has incompatible type "Hashable"; expected "Sized"
#    1205 if is_list_like(level) and len(level) == 1:  # type: ignore[arg-type]
#    1206     # GH 51583
#
# KeyboardInterrupt:
