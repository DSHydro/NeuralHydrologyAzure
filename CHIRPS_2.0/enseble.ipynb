# %%
import yaml
from pathlib import Path

model_dir= Path("runs/gauge_and_chirps_precip_seq_270_30_epochs_seq_270_hidden_256_dropout_04_fb_05_seed111_0402_180903")
scaler_path = model_dir / "train_data" / "train_data_scaler.yml"

with open(scaler_path, "r") as f:
    scaler = yaml.safe_load(f)

# %%
from neuralhydrology.utils.config import Config


cfg = Config(model_dir / "config.yml")

# %%
from neuralhydrology.datasetzoo import get_dataset

dataset = get_dataset(
    cfg=cfg,
    period="validation",
    is_train=False,
    scaler=scaler
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1511             variable = self._variables[name]
#    1512         except KeyError:
# -> 1513             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1514
#
# KeyError: 'basin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1614                 if isinstance(key, tuple):
#    1615                     message += f"\nHint: use a list to select multiple variables, for example `ds[{list(key)}]`"
# -> 1616                 raise KeyError(message) from e
#    1617
#
# ...
