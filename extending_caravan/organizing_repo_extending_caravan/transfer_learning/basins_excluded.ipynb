# %%
from pathlib import Path
import sys
import pandas as pd
import torch
import matplotlib.pyplot as plt
import xarray as xr
import yaml
import geopandas as gpd
import contextily as cx
from adjustText import adjust_text
import itertools


from neuralhydrology.nh_run import start_run, eval_run, finetune
from neuralhydrology.nh_run import continue_run
from neuralhydrology.utils.config import Config
from neuralhydrology.evaluation import get_tester, metrics

# %%
# # -------- Paths ---------
# CONFIG_PATH = Path("./basins_excluded.yml")
# RUNS_DIR = Path("runs")
# PLOTS_DIR = Path("./evaluation_plots")
# RUNS_DIR = Path("runs")
# PLOTS_DIR = Path("evaluation_plots")
# ATTRIBUTES_FILE= Path('./data/attributes/attributes_other.csv')

# %%
# precip_products = [
#     "era5land_total_precipitation",
#     "chirps_precipitation",
#     "mswep_precipitation"
# ]

# %%
# base_config_path = Path("basins_excluded.yml")

# with open(base_config_path, "r") as f:
#     base_config = yaml.safe_load(f)

# %%
# for r in range(1, len(precip_products) + 1):
#     for precip_combo in itertools.combinations(precip_products, r):
#         config = base_config.copy()

#         # Update dynamic inputs:
#         # Keep temperature and radiation, replace precip
#         config["dynamic_inputs"] = [
#             "surface_net_solar_radiation_mean",
#             "temperature_2m_max",
#             "temperature_2m_min",
#             *precip_combo
#         ]

#         # Create unique experiment name
#         precip_name = "_".join(precip_combo)
#         config["experiment_name"] = (
#             f"precip_{precip_name}"
#         )

#         # Save temporary config file
#         temp_config_path = Path(f"temp_{precip_name}")
#         with open(temp_config_path, "w") as f:
#             yaml.dump(config, f)

#         print(f"Running: {config['experiment_name']}")

#         # Run training
#         if torch.cuda.is_available() or torch.backends.mps.is_available():
#             start_run(config_file=temp_config_path)
#         else:
#             start_run(config_file=temp_config_path, gpu=-1)

# %%
# by default we assume that you have at least one CUDA-capable NVIDIA GPU or MacOS with Metal support
if torch.cuda.is_available() or torch.backends.mps.is_available():
    start_run(config_file=Path("all_basins.yml"))

# fall back to CPU-only mode
else:
    start_run(config_file=Path("all_basins.yml"), gpu=-1)
# Out:
# 2026-03-28 22:44:58,105: Logging to /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/output.log initialized.
# 2026-03-28 22:44:58,106: ### Folder structure created at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458
# 2026-03-28 22:44:58,106: ### Run configurations for 531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111
# 2026-03-28 22:44:58,106: experiment_name: 531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111
# 2026-03-28 22:44:58,107: run_dir: /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458
# 2026-03-28 22:44:58,107: train_basin_file: 531_basin.txt
# 2026-03-28 22:44:58,107: validation_basin_file: 531_basin.txt
# 2026-03-28 22:44:58,108: test_basin_file: 531_basin.txt
# 2026-03-28 22:44:58,108: train_start_date: 1999-10-01 00:00:00
# 2026-03-28 22:44:58,108: train_end_date: 2008-09-30 00:00:00
# 2026-03-28 22:44:58,109: validation_start_date: 1989-10-01 00:00:00
# 2026-03-28 22:44:58,109: validation_end_date: 1999-09-30 00:00:00
# 2026-03-28 22:44:58,109: seed: 111
# 2026-03-28 22:44:58,110: device: cuda:0
# 2026-03-28 22:44:58,110: validate_every: 1
# 2026-03-28 22:44:58,110: metrics: ['NSE', 'KGE', 'Alpha-NSE', 'Beta-NSE', 'Pearson-r', 'RMSE', 'MSE', 'Beta-KGE']
# 2026-03-28 22:44:58,111: model: cudalstm
# 2026-03-28 22:44:58,111: head: regression
# 2026-03-28 22:44:58,111: hidden_size: 256
# 2026-03-28 22:44:58,112: initial_forget_bias: 5
# 2026-03-28 22:44:58,114: output_dropout: 0.4
# 2026-03-28 22:44:58,114: output_activation: linear
# 2026-03-28 22:44:58,114: optimizer: Adam
# 2026-03-28 22:44:58,115: loss: NSE
# 2026-03-28 22:44:58,115: learning_rate: {0: 0.001}
# 2026-03-28 22:44:58,115: batch_size: 256
# 2026-03-28 22:44:58,116: epochs: 30
# 2026-03-28 22:44:58,117: clip_gradient_norm: 1
# 2026-03-28 22:44:58,117: predict_last_n: 1
# 2026-03-28 22:44:58,117: seq_length: 270
# 2026-03-28 22:44:58,118: num_workers: 4
# 2026-03-28 22:44:58,118: log_interval: 5
# 2026-03-28 22:44:58,118: log_tensorboard: True
# 2026-03-28 22:44:58,120: save_weights_every: 1
# 2026-03-28 22:44:58,120: save_validation_results: True
# 2026-03-28 22:44:58,121: data_dir: /inputs/data_updated_2
# 2026-03-28 22:44:58,121: dataset: generic
# 2026-03-28 22:44:58,122: dynamic_inputs: ['total_precipitation_sum', 'temperature_2m_max', 'temperature_2m_min', 'surface_net_solar_radiation_mean']
# 2026-03-28 22:44:58,122: target_variables: ['streamflow']
# 2026-03-28 22:44:58,123: static_attributes: ['ele_mt_sav', 'slp_dg_sav', 'area', 'snd_pc_sav', 'slt_pc_sav', 'cly_pc_sav', 'pet_mean_FAO_PM', 'aridity_FAO_PM', 'frac_snow', 'p_mean', 'high_prec_dur', 'low_prec_dur']
# 2026-03-28 22:44:58,123: number_of_basins: 531
# 2026-03-28 22:44:58,124: train_dir: /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/train_data
# 2026-03-28 22:44:58,124: img_log_dir: /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/img_log
# 2026-03-28 22:44:58,147: ### Device cuda:0 will be used for training
# 2026-03-28 22:44:59,377: Loading basin data into xarray data set.
# 100%|██████████| 531/531 [05:57<00:00,  1.48it/s]
# 2026-03-28 22:50:57,645: Calculating target variable stds per basin
# 100%|██████████| 531/531 [00:00<00:00, 1884.25it/s]
# 2026-03-28 22:50:57,989: Create lookup table and convert to pytorch tensor
# 100%|██████████| 531/531 [00:15<00:00, 35.09it/s]
# 2026-03-28 22:51:14,352: Validation set to validate every 1 epoch(s), but 'validate_n_random_basins' not set or set to zero. Will validate on the entire validation set.
# # Epoch 1: 100%|██████████| 6821/6821 [06:13<00:00, 18.24it/s, Loss: 0.0815]
# 2026-03-28 22:57:28,333: Epoch 1 average loss: avg_loss: 0.04757, avg_total_loss: 0.04757
# # Validation: 100%|██████████| 531/531 [16:51<00:00,  1.91s/it]
# 2026-03-28 23:14:20,149: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch001/validation_metrics.csv
# 2026-03-28 23:14:20,285: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch001/validation_results.p
# 2026-03-28 23:14:20,297: Epoch 1 average validation loss: 0.04010 -- Median validation metrics: avg_loss: 0.04010, NSE: 0.40245, KGE: 0.43121, Alpha-NSE: 0.60016, Beta-NSE: -0.02621, Pearson-r: 0.68285, RMSE: 1.89027, MSE: 3.57312, Beta-KGE: 0.95087
# # Epoch 2: 100%|██████████| 6821/6821 [06:22<00:00, 17.84it/s, Loss: 0.0081]
# 2026-03-28 23:20:42,698: Epoch 2 average loss: avg_loss: 0.05506, avg_total_loss: 0.05506
# # Validation: 100%|██████████| 531/531 [03:12<00:00,  2.76it/s]
# 2026-03-28 23:23:55,104: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch002/validation_metrics.csv
# 2026-03-28 23:23:55,237: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch002/validation_results.p
# 2026-03-28 23:23:55,248: Epoch 2 average validation loss: 0.03599 -- Median validation metrics: avg_loss: 0.03599, NSE: 0.45082, KGE: 0.49350, Alpha-NSE: 0.67761, Beta-NSE: 0.01081, Pearson-r: 0.70952, RMSE: 1.74884, MSE: 3.05846, Beta-KGE: 1.02197
# # Epoch 3: 100%|██████████| 6821/6821 [06:30<00:00, 17.46it/s, Loss: 0.0018]
# 2026-03-28 23:30:25,851: Epoch 3 average loss: avg_loss: 0.03326, avg_total_loss: 0.03326
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-28 23:33:39,583: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch003/validation_metrics.csv
# 2026-03-28 23:33:39,721: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch003/validation_results.p
# 2026-03-28 23:33:39,732: Epoch 3 average validation loss: 0.03536 -- Median validation metrics: avg_loss: 0.03536, NSE: 0.45467, KGE: 0.54299, Alpha-NSE: 0.70299, Beta-NSE: -0.02896, Pearson-r: 0.71357, RMSE: 1.77914, MSE: 3.16535, Beta-KGE: 0.93954
# # Epoch 4: 100%|██████████| 6821/6821 [06:33<00:00, 17.33it/s, Loss: 0.0043]
# 2026-03-28 23:40:13,220: Epoch 4 average loss: avg_loss: 0.03124, avg_total_loss: 0.03124
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.73it/s]
# 2026-03-28 23:43:27,949: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch004/validation_metrics.csv
# 2026-03-28 23:43:28,088: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch004/validation_results.p
# 2026-03-28 23:43:28,104: Epoch 4 average validation loss: 0.03503 -- Median validation metrics: avg_loss: 0.03503, NSE: 0.46635, KGE: 0.57599, Alpha-NSE: 0.80225, Beta-NSE: 0.02985, Pearson-r: 0.72496, RMSE: 1.72214, MSE: 2.96578, Beta-KGE: 1.05612
# # Epoch 5: 100%|██████████| 6821/6821 [06:31<00:00, 17.41it/s, Loss: 0.0109]
# 2026-03-28 23:49:59,942: Epoch 5 average loss: avg_loss: 0.02978, avg_total_loss: 0.02978
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-28 23:53:13,830: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch005/validation_metrics.csv
# 2026-03-28 23:53:13,966: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch005/validation_results.p
# 2026-03-28 23:53:13,980: Epoch 5 average validation loss: 0.03376 -- Median validation metrics: avg_loss: 0.03376, NSE: 0.47940, KGE: 0.54128, Alpha-NSE: 0.67206, Beta-NSE: -0.05018, Pearson-r: 0.72562, RMSE: 1.71837, MSE: 2.95281, Beta-KGE: 0.91327
# # Epoch 6: 100%|██████████| 6821/6821 [06:32<00:00, 17.38it/s, Loss: 0.0032]
# 2026-03-28 23:59:46,551: Epoch 6 average loss: avg_loss: 0.02872, avg_total_loss: 0.02872
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 00:03:00,357: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch006/validation_metrics.csv
# 2026-03-29 00:03:00,495: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch006/validation_results.p
# 2026-03-29 00:03:00,506: Epoch 6 average validation loss: 0.03394 -- Median validation metrics: avg_loss: 0.03394, NSE: 0.48654, KGE: 0.58872, Alpha-NSE: 0.77914, Beta-NSE: -0.01082, Pearson-r: 0.72928, RMSE: 1.71420, MSE: 2.93848, Beta-KGE: 0.98467
# # Epoch 7: 100%|██████████| 6821/6821 [06:35<00:00, 17.25it/s, Loss: 0.0001]
# 2026-03-29 00:09:35,915: Epoch 7 average loss: avg_loss: 0.02779, avg_total_loss: 0.02779
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 00:12:49,623: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch007/validation_metrics.csv
# 2026-03-29 00:12:49,762: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch007/validation_results.p
# 2026-03-29 00:12:49,773: Epoch 7 average validation loss: 0.03378 -- Median validation metrics: avg_loss: 0.03378, NSE: 0.47315, KGE: 0.58402, Alpha-NSE: 0.75581, Beta-NSE: 0.00120, Pearson-r: 0.72259, RMSE: 1.71096, MSE: 2.92740, Beta-KGE: 1.00242
# # Epoch 8: 100%|██████████| 6821/6821 [06:33<00:00, 17.34it/s, Loss: 0.0015]
# 2026-03-29 00:19:23,160: Epoch 8 average loss: avg_loss: 0.02730, avg_total_loss: 0.02730
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.75it/s]
# 2026-03-29 00:22:36,237: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch008/validation_metrics.csv
# 2026-03-29 00:22:36,372: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch008/validation_results.p
# 2026-03-29 00:22:36,383: Epoch 8 average validation loss: 0.03566 -- Median validation metrics: avg_loss: 0.03566, NSE: 0.46134, KGE: 0.55083, Alpha-NSE: 0.75994, Beta-NSE: 0.02291, Pearson-r: 0.72137, RMSE: 1.78210, MSE: 3.17589, Beta-KGE: 1.03897
# # Epoch 9: 100%|██████████| 6821/6821 [06:33<00:00, 17.34it/s, Loss: 0.0095]
# 2026-03-29 00:29:09,825: Epoch 9 average loss: avg_loss: 0.02645, avg_total_loss: 0.02645
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 00:32:23,761: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch009/validation_metrics.csv
# 2026-03-29 00:32:23,903: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch009/validation_results.p
# 2026-03-29 00:32:23,914: Epoch 9 average validation loss: 0.03378 -- Median validation metrics: avg_loss: 0.03378, NSE: 0.48119, KGE: 0.57949, Alpha-NSE: 0.77198, Beta-NSE: -0.00167, Pearson-r: 0.71961, RMSE: 1.69893, MSE: 2.88636, Beta-KGE: 0.99670
# # Epoch 10: 100%|██████████| 6821/6821 [06:35<00:00, 17.23it/s, Loss: 0.0007]
# 2026-03-29 00:38:59,823: Epoch 10 average loss: avg_loss: 0.02589, avg_total_loss: 0.02589
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 00:42:13,505: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch010/validation_metrics.csv
# 2026-03-29 00:42:13,653: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch010/validation_results.p
# 2026-03-29 00:42:13,664: Epoch 10 average validation loss: 0.03377 -- Median validation metrics: avg_loss: 0.03377, NSE: 0.48239, KGE: 0.57541, Alpha-NSE: 0.75409, Beta-NSE: -0.01938, Pearson-r: 0.72930, RMSE: 1.68199, MSE: 2.82910, Beta-KGE: 0.96305
# # Epoch 11: 100%|██████████| 6821/6821 [06:33<00:00, 17.34it/s, Loss: 0.0021]
# 2026-03-29 00:48:47,041: Epoch 11 average loss: avg_loss: 0.02550, avg_total_loss: 0.02550
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 00:52:00,564: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch011/validation_metrics.csv
# 2026-03-29 00:52:00,706: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch011/validation_results.p
# 2026-03-29 00:52:00,718: Epoch 11 average validation loss: 0.03425 -- Median validation metrics: avg_loss: 0.03425, NSE: 0.48270, KGE: 0.60037, Alpha-NSE: 0.80653, Beta-NSE: 0.00781, Pearson-r: 0.72690, RMSE: 1.73003, MSE: 2.99300, Beta-KGE: 1.01482
# # Epoch 12: 100%|██████████| 6821/6821 [06:34<00:00, 17.30it/s, Loss: 0.0069]
# 2026-03-29 00:58:35,085: Epoch 12 average loss: avg_loss: 0.02490, avg_total_loss: 0.02490
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 01:01:48,856: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch012/validation_metrics.csv
# 2026-03-29 01:01:48,998: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch012/validation_results.p
# 2026-03-29 01:01:49,010: Epoch 12 average validation loss: 0.03393 -- Median validation metrics: avg_loss: 0.03393, NSE: 0.47293, KGE: 0.59127, Alpha-NSE: 0.78195, Beta-NSE: -0.03032, Pearson-r: 0.72328, RMSE: 1.70536, MSE: 2.90826, Beta-KGE: 0.94778
# # Epoch 13: 100%|██████████| 6821/6821 [06:34<00:00, 17.30it/s, Loss: 0.0023]
# 2026-03-29 01:08:23,275: Epoch 13 average loss: avg_loss: 0.02442, avg_total_loss: 0.02442
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 01:11:37,293: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch013/validation_metrics.csv
# 2026-03-29 01:11:37,430: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch013/validation_results.p
# 2026-03-29 01:11:37,442: Epoch 13 average validation loss: 0.03434 -- Median validation metrics: avg_loss: 0.03434, NSE: 0.48097, KGE: 0.57509, Alpha-NSE: 0.73717, Beta-NSE: -0.06291, Pearson-r: 0.72048, RMSE: 1.71109, MSE: 2.92782, Beta-KGE: 0.88649
# # Epoch 14: 100%|██████████| 6821/6821 [06:33<00:00, 17.31it/s, Loss: 0.0075]
# 2026-03-29 01:18:11,412: Epoch 14 average loss: avg_loss: 0.02365, avg_total_loss: 0.02365
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 01:21:24,888: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch014/validation_metrics.csv
# 2026-03-29 01:21:25,026: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch014/validation_results.p
# 2026-03-29 01:21:25,036: Epoch 14 average validation loss: 0.03531 -- Median validation metrics: avg_loss: 0.03531, NSE: 0.47863, KGE: 0.60385, Alpha-NSE: 0.82978, Beta-NSE: 0.00414, Pearson-r: 0.72878, RMSE: 1.77497, MSE: 3.15053, Beta-KGE: 1.00774
# # Epoch 15: 100%|██████████| 6821/6821 [06:34<00:00, 17.28it/s, Loss: 0.0062]
# 2026-03-29 01:27:59,696: Epoch 15 average loss: avg_loss: 0.02324, avg_total_loss: 0.02324
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.74it/s]
# 2026-03-29 01:31:13,765: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch015/validation_metrics.csv
# 2026-03-29 01:31:13,902: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch015/validation_results.p
# 2026-03-29 01:31:13,913: Epoch 15 average validation loss: 0.03559 -- Median validation metrics: avg_loss: 0.03559, NSE: 0.46258, KGE: 0.60731, Alpha-NSE: 0.83263, Beta-NSE: 0.00075, Pearson-r: 0.72175, RMSE: 1.75975, MSE: 3.09671, Beta-KGE: 1.00133
# # Epoch 16: 100%|██████████| 6821/6821 [06:34<00:00, 17.31it/s, Loss: 0.0053]
# 2026-03-29 01:37:48,003: Epoch 16 average loss: avg_loss: 0.02296, avg_total_loss: 0.02296
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 01:41:01,748: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch016/validation_metrics.csv
# 2026-03-29 01:41:01,889: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch016/validation_results.p
# 2026-03-29 01:41:01,900: Epoch 16 average validation loss: 0.03645 -- Median validation metrics: avg_loss: 0.03645, NSE: 0.46518, KGE: 0.60677, Alpha-NSE: 0.86912, Beta-NSE: 0.03136, Pearson-r: 0.72272, RMSE: 1.80476, MSE: 3.25715, Beta-KGE: 1.05599
# # Epoch 17: 100%|██████████| 6821/6821 [06:34<00:00, 17.31it/s, Loss: 0.0051]
# 2026-03-29 01:47:36,060: Epoch 17 average loss: avg_loss: 0.02254, avg_total_loss: 0.02254
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.74it/s]
# 2026-03-29 01:50:50,199: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch017/validation_metrics.csv
# 2026-03-29 01:50:50,339: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch017/validation_results.p
# 2026-03-29 01:50:50,350: Epoch 17 average validation loss: 0.03544 -- Median validation metrics: avg_loss: 0.03544, NSE: 0.45900, KGE: 0.60163, Alpha-NSE: 0.81698, Beta-NSE: -0.00527, Pearson-r: 0.72120, RMSE: 1.73198, MSE: 2.99974, Beta-KGE: 0.99184
# # Epoch 18: 100%|██████████| 6821/6821 [06:35<00:00, 17.26it/s, Loss: 0.0019]
# 2026-03-29 01:57:25,654: Epoch 18 average loss: avg_loss: 0.02218, avg_total_loss: 0.02218
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.74it/s]
# 2026-03-29 02:00:39,791: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch018/validation_metrics.csv
# 2026-03-29 02:00:39,937: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch018/validation_results.p
# 2026-03-29 02:00:39,949: Epoch 18 average validation loss: 0.03481 -- Median validation metrics: avg_loss: 0.03481, NSE: 0.46462, KGE: 0.61816, Alpha-NSE: 0.84241, Beta-NSE: -0.01540, Pearson-r: 0.72360, RMSE: 1.74358, MSE: 3.04008, Beta-KGE: 0.97346
# # Epoch 19: 100%|██████████| 6821/6821 [06:33<00:00, 17.34it/s, Loss: 0.0065]
# 2026-03-29 02:07:13,359: Epoch 19 average loss: avg_loss: 0.02152, avg_total_loss: 0.02152
# # Validation: 100%|██████████| 531/531 [03:12<00:00,  2.76it/s]
# 2026-03-29 02:10:26,066: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch019/validation_metrics.csv
# 2026-03-29 02:10:26,205: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch019/validation_results.p
# 2026-03-29 02:10:26,216: Epoch 19 average validation loss: 0.03604 -- Median validation metrics: avg_loss: 0.03604, NSE: 0.46703, KGE: 0.61804, Alpha-NSE: 0.83477, Beta-NSE: 0.00709, Pearson-r: 0.71964, RMSE: 1.79296, MSE: 3.21471, Beta-KGE: 1.01323
# # Epoch 20: 100%|██████████| 6821/6821 [06:37<00:00, 17.18it/s, Loss: 0.0064]
# 2026-03-29 02:17:03,294: Epoch 20 average loss: avg_loss: 0.02123, avg_total_loss: 0.02123
# # Validation: 100%|██████████| 531/531 [03:15<00:00,  2.72it/s]
# 2026-03-29 02:20:18,421: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch020/validation_metrics.csv
# 2026-03-29 02:20:18,563: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch020/validation_results.p
# 2026-03-29 02:20:18,575: Epoch 20 average validation loss: 0.03545 -- Median validation metrics: avg_loss: 0.03545, NSE: 0.47011, KGE: 0.60018, Alpha-NSE: 0.81934, Beta-NSE: -0.00368, Pearson-r: 0.71842, RMSE: 1.73749, MSE: 3.01886, Beta-KGE: 0.99397
# # Epoch 21: 100%|██████████| 6821/6821 [06:35<00:00, 17.26it/s, Loss: 0.0074]
# 2026-03-29 02:26:53,748: Epoch 21 average loss: avg_loss: 0.02112, avg_total_loss: 0.02112
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.75it/s]
# 2026-03-29 02:30:06,970: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch021/validation_metrics.csv
# 2026-03-29 02:30:07,110: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch021/validation_results.p
# 2026-03-29 02:30:07,122: Epoch 21 average validation loss: 0.03368 -- Median validation metrics: avg_loss: 0.03368, NSE: 0.48855, KGE: 0.61691, Alpha-NSE: 0.79281, Beta-NSE: -0.00690, Pearson-r: 0.72760, RMSE: 1.70420, MSE: 2.90429, Beta-KGE: 0.99005
# # Epoch 22: 100%|██████████| 6821/6821 [06:34<00:00, 17.30it/s, Loss: 0.0108]
# 2026-03-29 02:36:41,329: Epoch 22 average loss: avg_loss: 0.02089, avg_total_loss: 0.02089
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.74it/s]
# 2026-03-29 02:39:55,498: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch022/validation_metrics.csv
# 2026-03-29 02:39:55,639: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch022/validation_results.p
# 2026-03-29 02:39:55,650: Epoch 22 average validation loss: 0.03707 -- Median validation metrics: avg_loss: 0.03707, NSE: 0.45588, KGE: 0.59325, Alpha-NSE: 0.82826, Beta-NSE: -0.01809, Pearson-r: 0.70988, RMSE: 1.78290, MSE: 3.17875, Beta-KGE: 0.96742
# # Epoch 23: 100%|██████████| 6821/6821 [06:37<00:00, 17.16it/s, Loss: 0.0041]
# 2026-03-29 02:46:33,152: Epoch 23 average loss: avg_loss: 0.02053, avg_total_loss: 0.02053
# # Validation: 100%|██████████| 531/531 [03:15<00:00,  2.72it/s]
# 2026-03-29 02:49:48,190: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch023/validation_metrics.csv
# 2026-03-29 02:49:48,331: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch023/validation_results.p
# 2026-03-29 02:49:48,342: Epoch 23 average validation loss: 0.03672 -- Median validation metrics: avg_loss: 0.03672, NSE: 0.46615, KGE: 0.60738, Alpha-NSE: 0.83302, Beta-NSE: 0.01303, Pearson-r: 0.71794, RMSE: 1.76379, MSE: 3.11095, Beta-KGE: 1.02834
# # Epoch 24: 100%|██████████| 6821/6821 [06:36<00:00, 17.21it/s, Loss: 0.8787]
# 2026-03-29 02:56:24,616: Epoch 24 average loss: avg_loss: 0.02022, avg_total_loss: 0.02022
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 02:59:38,088: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch024/validation_metrics.csv
# 2026-03-29 02:59:38,224: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch024/validation_results.p
# 2026-03-29 02:59:38,235: Epoch 24 average validation loss: 0.03777 -- Median validation metrics: avg_loss: 0.03777, NSE: 0.45110, KGE: 0.62464, Alpha-NSE: 0.86870, Beta-NSE: 0.00754, Pearson-r: 0.71788, RMSE: 1.83595, MSE: 3.37073, Beta-KGE: 1.01547
# # Epoch 25: 100%|██████████| 6821/6821 [06:35<00:00, 17.23it/s, Loss: 0.0013]
# 2026-03-29 03:06:14,032: Epoch 25 average loss: avg_loss: 0.01987, avg_total_loss: 0.01987
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.74it/s]
# 2026-03-29 03:09:28,055: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch025/validation_metrics.csv
# 2026-03-29 03:09:28,199: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch025/validation_results.p
# 2026-03-29 03:09:28,210: Epoch 25 average validation loss: 0.03492 -- Median validation metrics: avg_loss: 0.03492, NSE: 0.46444, KGE: 0.62181, Alpha-NSE: 0.81856, Beta-NSE: 0.01204, Pearson-r: 0.71546, RMSE: 1.75425, MSE: 3.07738, Beta-KGE: 1.02015
# # Epoch 26: 100%|██████████| 6821/6821 [06:35<00:00, 17.25it/s, Loss: 0.0008]
# 2026-03-29 03:16:03,733: Epoch 26 average loss: avg_loss: 0.01948, avg_total_loss: 0.01948
# # Validation: 100%|██████████| 531/531 [03:13<00:00,  2.74it/s]
# 2026-03-29 03:19:17,731: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch026/validation_metrics.csv
# 2026-03-29 03:19:17,867: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch026/validation_results.p
# 2026-03-29 03:19:17,878: Epoch 26 average validation loss: 0.03480 -- Median validation metrics: avg_loss: 0.03480, NSE: 0.47973, KGE: 0.60936, Alpha-NSE: 0.80528, Beta-NSE: -0.01288, Pearson-r: 0.72349, RMSE: 1.71747, MSE: 2.94971, Beta-KGE: 0.97889
# # Epoch 27: 100%|██████████| 6821/6821 [06:34<00:00, 17.29it/s, Loss: 0.0014]
# 2026-03-29 03:25:52,440: Epoch 27 average loss: avg_loss: 0.01932, avg_total_loss: 0.01932
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.73it/s]
# 2026-03-29 03:29:06,724: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch027/validation_metrics.csv
# 2026-03-29 03:29:06,870: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch027/validation_results.p
# 2026-03-29 03:29:06,882: Epoch 27 average validation loss: 0.03619 -- Median validation metrics: avg_loss: 0.03619, NSE: 0.45153, KGE: 0.60002, Alpha-NSE: 0.86788, Beta-NSE: 0.01685, Pearson-r: 0.71706, RMSE: 1.77000, MSE: 3.13288, Beta-KGE: 1.02755
# # Epoch 28: 100%|██████████| 6821/6821 [06:35<00:00, 17.26it/s, Loss: 0.0001]
# 2026-03-29 03:35:42,131: Epoch 28 average loss: avg_loss: 0.01914, avg_total_loss: 0.01914
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.73it/s]
# 2026-03-29 03:38:56,499: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch028/validation_metrics.csv
# 2026-03-29 03:38:56,636: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch028/validation_results.p
# 2026-03-29 03:38:56,647: Epoch 28 average validation loss: 0.03523 -- Median validation metrics: avg_loss: 0.03523, NSE: 0.47971, KGE: 0.61170, Alpha-NSE: 0.80563, Beta-NSE: -0.02464, Pearson-r: 0.72204, RMSE: 1.73761, MSE: 3.01927, Beta-KGE: 0.95651
# # Epoch 29: 100%|██████████| 6821/6821 [06:37<00:00, 17.17it/s, Loss: 0.0088]
# 2026-03-29 03:45:33,936: Epoch 29 average loss: avg_loss: 0.01897, avg_total_loss: 0.01897
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.73it/s]
# 2026-03-29 03:48:48,410: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch029/validation_metrics.csv
# 2026-03-29 03:48:48,550: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch029/validation_results.p
# 2026-03-29 03:48:48,567: Epoch 29 average validation loss: 0.03593 -- Median validation metrics: avg_loss: 0.03593, NSE: 0.46085, KGE: 0.59855, Alpha-NSE: 0.83159, Beta-NSE: -0.00808, Pearson-r: 0.71281, RMSE: 1.72798, MSE: 2.98592, Beta-KGE: 0.98841
# # Epoch 30: 100%|██████████| 6821/6821 [06:36<00:00, 17.18it/s, Loss: 0.0025]
# 2026-03-29 03:55:25,570: Epoch 30 average loss: avg_loss: 0.01860, avg_total_loss: 0.01860
# # Validation: 100%|██████████| 531/531 [03:14<00:00,  2.73it/s]
# 2026-03-29 03:58:39,955: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch030/validation_metrics.csv
# 2026-03-29 03:58:40,093: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/validation/model_epoch030/validation_results.p
# 2026-03-29 03:58:40,104: Epoch 30 average validation loss: 0.03635 -- Median validation metrics: avg_loss: 0.03635, NSE: 0.46054, KGE: 0.61632, Alpha-NSE: 0.87254, Beta-NSE: 0.01580, Pearson-r: 0.72289, RMSE: 1.77530, MSE: 3.15169, Beta-KGE: 1.02640

# %%
# finetune

# %%
finetune(Path("finetune.yml"))
# Out:
# 2026-03-30 00:47:38,617: Logging to /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/output.log initialized.
# 2026-03-30 00:47:38,618: ### Folder structure created at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738
# 2026-03-30 00:47:38,619: ### Start finetuning with pretrained model stored in runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458
# 2026-03-30 00:47:38,619: ### Run configurations for finetune_UY_basins_head
# 2026-03-30 00:47:38,619: batch_size: 256
# 2026-03-30 00:47:38,620: clip_gradient_norm: 1
# 2026-03-30 00:47:38,620: commit_hash: None
# 2026-03-30 00:47:38,620: data_dir: ../data
# 2026-03-30 00:47:38,621: dataset: generic
# 2026-03-30 00:47:38,621: device: cuda:0
# 2026-03-30 00:47:38,622: dynamic_inputs: ['total_precipitation_sum', 'temperature_2m_max', 'temperature_2m_min', 'surface_net_solar_radiation_mean']
# 2026-03-30 00:47:38,622: epochs: 30
# 2026-03-30 00:47:38,622: experiment_name: finetune_UY_basins_head
# 2026-03-30 00:47:38,623: head: regression
# 2026-03-30 00:47:38,623: hidden_size: 256
# 2026-03-30 00:47:38,623: img_log_dir: /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/img_log
# 2026-03-30 00:47:38,624: initial_forget_bias: 5
# 2026-03-30 00:47:38,624: learning_rate: {0: 0.001}
# 2026-03-30 00:47:38,626: log_interval: 5
# 2026-03-30 00:47:38,626: log_tensorboard: True
# 2026-03-30 00:47:38,626: loss: NSE
# 2026-03-30 00:47:38,627: metrics: ['NSE', 'KGE', 'Alpha-NSE', 'Beta-NSE', 'Pearson-r', 'RMSE', 'MSE', 'Beta-KGE']
# 2026-03-30 00:47:38,628: model: cudalstm
# 2026-03-30 00:47:38,628: num_workers: 4
# 2026-03-30 00:47:38,628: number_of_basins: 11
# 2026-03-30 00:47:38,629: optimizer: Adam
# 2026-03-30 00:47:38,629: output_activation: linear
# 2026-03-30 00:47:38,629: output_dropout: 0.4
# 2026-03-30 00:47:38,630: package_version: 1.12.0
# 2026-03-30 00:47:38,630: predict_last_n: 1
# 2026-03-30 00:47:38,630: run_dir: /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738
# 2026-03-30 00:47:38,631: save_validation_results: True
# 2026-03-30 00:47:38,631: save_weights_every: 1
# 2026-03-30 00:47:38,631: seed: 111
# 2026-03-30 00:47:38,633: seq_length: 270
# 2026-03-30 00:47:38,633: static_attributes: ['ele_mt_sav', 'slp_dg_sav', 'area', 'snd_pc_sav', 'slt_pc_sav', 'cly_pc_sav', 'pet_mean_FAO_PM', 'aridity_FAO_PM', 'frac_snow', 'p_mean', 'high_prec_dur', 'low_prec_dur']
# 2026-03-30 00:47:38,633: target_variables: ['streamflow']
# 2026-03-30 00:47:38,634: test_basin_file: basins.txt
# 2026-03-30 00:47:38,634: train_basin_file: basins.txt
# 2026-03-30 00:47:38,634: train_dir: /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/train_data
# 2026-03-30 00:47:38,635: train_end_date: 2008-09-30 00:00:00
# 2026-03-30 00:47:38,635: train_start_date: 1999-10-01 00:00:00
# 2026-03-30 00:47:38,635: validate_every: 1
# 2026-03-30 00:47:38,636: validation_basin_file: basins.txt
# 2026-03-30 00:47:38,637: validation_end_date: 1999-09-30 00:00:00
# 2026-03-30 00:47:38,637: validation_start_date: 1989-10-01 00:00:00
# 2026-03-30 00:47:38,638: finetune_modules: ['head']
# 2026-03-30 00:47:38,638: base_run_dir: runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458
# 2026-03-30 00:47:38,639: is_finetuning: True
# 2026-03-30 00:47:38,639: is_continue_training: False
# 2026-03-30 00:47:38,640: ### Device cuda:0 will be used for training
# 2026-03-30 00:47:39,142: Loading basin data into xarray data set.
# 100%|██████████| 11/11 [00:00<00:00, 67.16it/s]
# 2026-03-30 00:47:39,317: Calculating target variable stds per basin
# 100%|██████████| 11/11 [00:00<00:00, 1467.52it/s]
# 2026-03-30 00:47:39,328: Create lookup table and convert to pytorch tensor
# 100%|██████████| 11/11 [00:00<00:00, 46.63it/s]
# 2026-03-30 00:47:39,584: Starting training from checkpoint runs/531_caravan_precip_seq_270_30_epochs_hidden_256_dropout_04_fb_05_seed111_2803_224458/model_epoch030.pt
# 2026-03-30 00:47:39,597: Validation set to validate every 1 epoch(s), but 'validate_n_random_basins' not set or set to zero. Will validate on the entire validation set.
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/training/basetrainer.py:160: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(str(checkpoint_path), map_location=self.device))
# # Epoch 1: 100%|██████████| 132/132 [00:03<00:00, 35.69it/s, Loss: 0.0404]
# 2026-03-30 00:47:43,304: Epoch 1 average loss: avg_loss: 0.05330, avg_total_loss: 0.05330
# # Validation: 100%|██████████| 11/11 [00:09<00:00,  1.16it/s]
# 2026-03-30 00:47:52,829: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch001/validation_metrics.csv
# 2026-03-30 00:47:52,832: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch001/validation_results.p
# 2026-03-30 00:47:52,834: Epoch 1 average validation loss: 0.06724 -- Median validation metrics: avg_loss: 0.06724, NSE: 0.26621, KGE: 0.31602, Alpha-NSE: 0.59292, Beta-NSE: 0.07417, Pearson-r: 0.52819, RMSE: 2.62724, MSE: 6.90238, Beta-KGE: 1.15913
# # Epoch 2: 100%|██████████| 132/132 [00:03<00:00, 37.14it/s, Loss: 0.0731]
# 2026-03-30 00:47:56,392: Epoch 2 average loss: avg_loss: 0.05077, avg_total_loss: 0.05077
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-03-30 00:48:00,253: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch002/validation_metrics.csv
# 2026-03-30 00:48:00,257: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch002/validation_results.p
# 2026-03-30 00:48:00,259: Epoch 2 average validation loss: 0.06494 -- Median validation metrics: avg_loss: 0.06494, NSE: 0.28471, KGE: 0.28588, Alpha-NSE: 0.57996, Beta-NSE: 0.10243, Pearson-r: 0.54143, RMSE: 2.58982, MSE: 6.70717, Beta-KGE: 1.23308
# # Epoch 3: 100%|██████████| 132/132 [00:03<00:00, 36.58it/s, Loss: 0.2313]
# 2026-03-30 00:48:03,871: Epoch 3 average loss: avg_loss: 0.05002, avg_total_loss: 0.05002
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-03-30 00:48:07,738: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch003/validation_metrics.csv
# 2026-03-30 00:48:07,741: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch003/validation_results.p
# 2026-03-30 00:48:07,744: Epoch 3 average validation loss: 0.06293 -- Median validation metrics: avg_loss: 0.06293, NSE: 0.29219, KGE: 0.28944, Alpha-NSE: 0.57483, Beta-NSE: 0.09436, Pearson-r: 0.55062, RMSE: 2.52693, MSE: 6.38539, Beta-KGE: 1.22407
# # Epoch 4: 100%|██████████| 132/132 [00:03<00:00, 36.66it/s, Loss: 0.0545]
# 2026-03-30 00:48:11,348: Epoch 4 average loss: avg_loss: 0.04822, avg_total_loss: 0.04822
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.85it/s]
# 2026-03-30 00:48:15,211: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch004/validation_metrics.csv
# 2026-03-30 00:48:15,215: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch004/validation_results.p
# 2026-03-30 00:48:15,218: Epoch 4 average validation loss: 0.06142 -- Median validation metrics: avg_loss: 0.06142, NSE: 0.29146, KGE: 0.30464, Alpha-NSE: 0.57478, Beta-NSE: 0.08297, Pearson-r: 0.55299, RMSE: 2.44610, MSE: 5.98342, Beta-KGE: 1.17719
# # Epoch 5: 100%|██████████| 132/132 [00:03<00:00, 36.87it/s, Loss: 0.0904]
# 2026-03-30 00:48:18,802: Epoch 5 average loss: avg_loss: 0.04794, avg_total_loss: 0.04794
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.66it/s]
# 2026-03-30 00:48:22,943: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch005/validation_metrics.csv
# 2026-03-30 00:48:22,946: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch005/validation_results.p
# 2026-03-30 00:48:22,965: Epoch 5 average validation loss: 0.06106 -- Median validation metrics: avg_loss: 0.06106, NSE: 0.29834, KGE: 0.29506, Alpha-NSE: 0.57915, Beta-NSE: 0.09601, Pearson-r: 0.55677, RMSE: 2.38482, MSE: 5.68739, Beta-KGE: 1.22795
# # Epoch 6: 100%|██████████| 132/132 [00:03<00:00, 36.86it/s, Loss: 0.0306]
# 2026-03-30 00:48:26,550: Epoch 6 average loss: avg_loss: 0.04703, avg_total_loss: 0.04703
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.84it/s]
# 2026-03-30 00:48:30,426: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch006/validation_metrics.csv
# 2026-03-30 00:48:30,429: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch006/validation_results.p
# 2026-03-30 00:48:30,432: Epoch 6 average validation loss: 0.05887 -- Median validation metrics: avg_loss: 0.05887, NSE: 0.30050, KGE: 0.30676, Alpha-NSE: 0.57150, Beta-NSE: 0.07287, Pearson-r: 0.55728, RMSE: 2.26695, MSE: 5.13905, Beta-KGE: 1.19062
# # Epoch 7: 100%|██████████| 132/132 [00:03<00:00, 36.28it/s, Loss: 0.0219]
# 2026-03-30 00:48:34,073: Epoch 7 average loss: avg_loss: 0.04639, avg_total_loss: 0.04639
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.83it/s]
# 2026-03-30 00:48:37,964: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch007/validation_metrics.csv
# 2026-03-30 00:48:37,967: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch007/validation_results.p
# 2026-03-30 00:48:37,970: Epoch 7 average validation loss: 0.05912 -- Median validation metrics: avg_loss: 0.05912, NSE: 0.30013, KGE: 0.30622, Alpha-NSE: 0.58299, Beta-NSE: 0.08505, Pearson-r: 0.55557, RMSE: 2.24865, MSE: 5.05645, Beta-KGE: 1.21905
# # Epoch 8: 100%|██████████| 132/132 [00:03<00:00, 36.70it/s, Loss: 0.0174]
# 2026-03-30 00:48:41,570: Epoch 8 average loss: avg_loss: 0.04681, avg_total_loss: 0.04681
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.83it/s]
# 2026-03-30 00:48:45,463: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch008/validation_metrics.csv
# 2026-03-30 00:48:45,467: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch008/validation_results.p
# 2026-03-30 00:48:45,469: Epoch 8 average validation loss: 0.05863 -- Median validation metrics: avg_loss: 0.05863, NSE: 0.29940, KGE: 0.30526, Alpha-NSE: 0.58267, Beta-NSE: 0.09821, Pearson-r: 0.55614, RMSE: 2.18582, MSE: 4.77780, Beta-KGE: 1.22147
# # Epoch 9: 100%|██████████| 132/132 [00:03<00:00, 36.34it/s, Loss: 0.0338]
# 2026-03-30 00:48:49,105: Epoch 9 average loss: avg_loss: 0.04644, avg_total_loss: 0.04644
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-03-30 00:48:53,119: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch009/validation_metrics.csv
# 2026-03-30 00:48:53,123: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch009/validation_results.p
# 2026-03-30 00:48:53,125: Epoch 9 average validation loss: 0.05730 -- Median validation metrics: avg_loss: 0.05730, NSE: 0.29844, KGE: 0.30978, Alpha-NSE: 0.58146, Beta-NSE: 0.07858, Pearson-r: 0.55882, RMSE: 2.16752, MSE: 4.69816, Beta-KGE: 1.18390
# # Epoch 10: 100%|██████████| 132/132 [00:03<00:00, 36.25it/s, Loss: 0.0165]
# 2026-03-30 00:48:56,771: Epoch 10 average loss: avg_loss: 0.04593, avg_total_loss: 0.04593
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.83it/s]
# 2026-03-30 00:49:00,672: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch010/validation_metrics.csv
# 2026-03-30 00:49:00,676: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch010/validation_results.p
# 2026-03-30 00:49:00,678: Epoch 10 average validation loss: 0.05704 -- Median validation metrics: avg_loss: 0.05704, NSE: 0.29569, KGE: 0.29012, Alpha-NSE: 0.57324, Beta-NSE: 0.10058, Pearson-r: 0.55638, RMSE: 2.17098, MSE: 4.71315, Beta-KGE: 1.25177
# # Epoch 11: 100%|██████████| 132/132 [00:03<00:00, 36.73it/s, Loss: 0.0224]
# 2026-03-30 00:49:04,275: Epoch 11 average loss: avg_loss: 0.04583, avg_total_loss: 0.04583
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.65it/s]
# 2026-03-30 00:49:08,440: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch011/validation_metrics.csv
# 2026-03-30 00:49:08,444: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch011/validation_results.p
# 2026-03-30 00:49:08,446: Epoch 11 average validation loss: 0.05630 -- Median validation metrics: avg_loss: 0.05630, NSE: 0.29953, KGE: 0.30952, Alpha-NSE: 0.58023, Beta-NSE: 0.08193, Pearson-r: 0.55847, RMSE: 2.16483, MSE: 4.68651, Beta-KGE: 1.20578
# # Epoch 12: 100%|██████████| 132/132 [00:03<00:00, 36.48it/s, Loss: 0.0239]
# 2026-03-30 00:49:12,067: Epoch 12 average loss: avg_loss: 0.04580, avg_total_loss: 0.04580
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.82it/s]
# 2026-03-30 00:49:15,979: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch012/validation_metrics.csv
# 2026-03-30 00:49:15,982: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch012/validation_results.p
# 2026-03-30 00:49:15,985: Epoch 12 average validation loss: 0.05555 -- Median validation metrics: avg_loss: 0.05555, NSE: 0.29855, KGE: 0.30406, Alpha-NSE: 0.56987, Beta-NSE: 0.07606, Pearson-r: 0.55815, RMSE: 2.16118, MSE: 4.67068, Beta-KGE: 1.20158
# # Epoch 13: 100%|██████████| 132/132 [00:03<00:00, 36.43it/s, Loss: 0.0390]
# 2026-03-30 00:49:19,611: Epoch 13 average loss: avg_loss: 0.04582, avg_total_loss: 0.04582
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.82it/s]
# 2026-03-30 00:49:23,518: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch013/validation_metrics.csv
# 2026-03-30 00:49:23,522: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch013/validation_results.p
# 2026-03-30 00:49:23,525: Epoch 13 average validation loss: 0.05584 -- Median validation metrics: avg_loss: 0.05584, NSE: 0.29475, KGE: 0.29681, Alpha-NSE: 0.57511, Beta-NSE: 0.10151, Pearson-r: 0.55927, RMSE: 2.17705, MSE: 4.73955, Beta-KGE: 1.25299
# # Epoch 14: 100%|██████████| 132/132 [00:03<00:00, 36.48it/s, Loss: 0.0523]
# 2026-03-30 00:49:27,147: Epoch 14 average loss: avg_loss: 0.04518, avg_total_loss: 0.04518
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.82it/s]
# 2026-03-30 00:49:31,061: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch014/validation_metrics.csv
# 2026-03-30 00:49:31,065: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch014/validation_results.p
# 2026-03-30 00:49:31,068: Epoch 14 average validation loss: 0.05626 -- Median validation metrics: avg_loss: 0.05626, NSE: 0.29433, KGE: 0.29328, Alpha-NSE: 0.58627, Beta-NSE: 0.11564, Pearson-r: 0.56236, RMSE: 2.18465, MSE: 4.77269, Beta-KGE: 1.26388
# # Epoch 15: 100%|██████████| 132/132 [00:03<00:00, 36.41it/s, Loss: 0.0389]
# 2026-03-30 00:49:34,696: Epoch 15 average loss: avg_loss: 0.04505, avg_total_loss: 0.04505
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.64it/s]
# 2026-03-30 00:49:38,878: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch015/validation_metrics.csv
# 2026-03-30 00:49:38,881: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch015/validation_results.p
# 2026-03-30 00:49:38,884: Epoch 15 average validation loss: 0.05648 -- Median validation metrics: avg_loss: 0.05648, NSE: 0.29225, KGE: 0.28981, Alpha-NSE: 0.59629, Beta-NSE: 0.12488, Pearson-r: 0.56328, RMSE: 2.19954, MSE: 4.83799, Beta-KGE: 1.29178
# # Epoch 16: 100%|██████████| 132/132 [00:03<00:00, 36.52it/s, Loss: 0.0896]
# 2026-03-30 00:49:42,502: Epoch 16 average loss: avg_loss: 0.04536, avg_total_loss: 0.04536
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.81it/s]
# 2026-03-30 00:49:46,421: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch016/validation_metrics.csv
# 2026-03-30 00:49:46,424: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch016/validation_results.p
# 2026-03-30 00:49:46,427: Epoch 16 average validation loss: 0.05427 -- Median validation metrics: avg_loss: 0.05427, NSE: 0.29871, KGE: 0.32432, Alpha-NSE: 0.58150, Beta-NSE: 0.08105, Pearson-r: 0.55976, RMSE: 2.17207, MSE: 4.71787, Beta-KGE: 1.18819
# # Epoch 17: 100%|██████████| 132/132 [00:03<00:00, 36.70it/s, Loss: 0.0327]
# 2026-03-30 00:49:50,026: Epoch 17 average loss: avg_loss: 0.04499, avg_total_loss: 0.04499
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.81it/s]
# 2026-03-30 00:49:53,943: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch017/validation_metrics.csv
# 2026-03-30 00:49:53,947: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch017/validation_results.p
# 2026-03-30 00:49:53,949: Epoch 17 average validation loss: 0.05448 -- Median validation metrics: avg_loss: 0.05448, NSE: 0.29776, KGE: 0.31102, Alpha-NSE: 0.58917, Beta-NSE: 0.09039, Pearson-r: 0.56245, RMSE: 2.18007, MSE: 4.75272, Beta-KGE: 1.21504
# # Epoch 18: 100%|██████████| 132/132 [00:03<00:00, 34.65it/s, Loss: 0.0228]
# 2026-03-30 00:49:57,762: Epoch 18 average loss: avg_loss: 0.04475, avg_total_loss: 0.04475
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.78it/s]
# 2026-03-30 00:50:01,733: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch018/validation_metrics.csv
# 2026-03-30 00:50:01,736: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch018/validation_results.p
# 2026-03-30 00:50:01,739: Epoch 18 average validation loss: 0.05533 -- Median validation metrics: avg_loss: 0.05533, NSE: 0.29419, KGE: 0.30285, Alpha-NSE: 0.59882, Beta-NSE: 0.12203, Pearson-r: 0.56249, RMSE: 2.19947, MSE: 4.83765, Beta-KGE: 1.27791
# # Epoch 19: 100%|██████████| 132/132 [00:03<00:00, 36.46it/s, Loss: 0.0365]
# 2026-03-30 00:50:05,363: Epoch 19 average loss: avg_loss: 0.04464, avg_total_loss: 0.04464
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.81it/s]
# 2026-03-30 00:50:09,279: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch019/validation_metrics.csv
# 2026-03-30 00:50:09,283: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch019/validation_results.p
# 2026-03-30 00:50:09,285: Epoch 19 average validation loss: 0.05481 -- Median validation metrics: avg_loss: 0.05481, NSE: 0.29321, KGE: 0.31539, Alpha-NSE: 0.60668, Beta-NSE: 0.10058, Pearson-r: 0.56566, RMSE: 2.20258, MSE: 4.85137, Beta-KGE: 1.22239
# # Epoch 20: 100%|██████████| 132/132 [00:03<00:00, 36.51it/s, Loss: 0.0351]
# 2026-03-30 00:50:12,904: Epoch 20 average loss: avg_loss: 0.04465, avg_total_loss: 0.04465
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.63it/s]
# 2026-03-30 00:50:17,098: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch020/validation_metrics.csv
# 2026-03-30 00:50:17,102: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch020/validation_results.p
# 2026-03-30 00:50:17,104: Epoch 20 average validation loss: 0.05483 -- Median validation metrics: avg_loss: 0.05483, NSE: 0.29091, KGE: 0.31484, Alpha-NSE: 0.60524, Beta-NSE: 0.12224, Pearson-r: 0.56684, RMSE: 2.21193, MSE: 4.89265, Beta-KGE: 1.28828
# # Epoch 21: 100%|██████████| 132/132 [00:03<00:00, 36.11it/s, Loss: 0.0707]
# 2026-03-30 00:50:20,763: Epoch 21 average loss: avg_loss: 0.04493, avg_total_loss: 0.04493
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.80it/s]
# 2026-03-30 00:50:24,696: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch021/validation_metrics.csv
# 2026-03-30 00:50:24,699: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch021/validation_results.p
# 2026-03-30 00:50:24,702: Epoch 21 average validation loss: 0.05442 -- Median validation metrics: avg_loss: 0.05442, NSE: 0.29412, KGE: 0.31025, Alpha-NSE: 0.60283, Beta-NSE: 0.09890, Pearson-r: 0.56663, RMSE: 2.19828, MSE: 4.83242, Beta-KGE: 1.24582
# # Epoch 22: 100%|██████████| 132/132 [00:03<00:00, 35.77it/s, Loss: 0.0215]
# 2026-03-30 00:50:28,395: Epoch 22 average loss: avg_loss: 0.04472, avg_total_loss: 0.04472
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.81it/s]
# 2026-03-30 00:50:32,323: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch022/validation_metrics.csv
# 2026-03-30 00:50:32,326: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch022/validation_results.p
# 2026-03-30 00:50:32,329: Epoch 22 average validation loss: 0.05334 -- Median validation metrics: avg_loss: 0.05334, NSE: 0.29755, KGE: 0.33423, Alpha-NSE: 0.59877, Beta-NSE: 0.07308, Pearson-r: 0.56552, RMSE: 2.18524, MSE: 4.77528, Beta-KGE: 1.14321
# # Epoch 23: 100%|██████████| 132/132 [00:03<00:00, 36.02it/s, Loss: 0.0372]
# 2026-03-30 00:50:35,997: Epoch 23 average loss: avg_loss: 0.04487, avg_total_loss: 0.04487
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.81it/s]
# 2026-03-30 00:50:39,922: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch023/validation_metrics.csv
# 2026-03-30 00:50:39,926: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch023/validation_results.p
# 2026-03-30 00:50:39,929: Epoch 23 average validation loss: 0.05375 -- Median validation metrics: avg_loss: 0.05375, NSE: 0.29316, KGE: 0.30048, Alpha-NSE: 0.59309, Beta-NSE: 0.10533, Pearson-r: 0.56523, RMSE: 2.19344, MSE: 4.81116, Beta-KGE: 1.25452
# # Epoch 24: 100%|██████████| 132/132 [00:03<00:00, 36.43it/s, Loss: 0.0492]
# 2026-03-30 00:50:43,555: Epoch 24 average loss: avg_loss: 0.04461, avg_total_loss: 0.04461
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.80it/s]
# 2026-03-30 00:50:47,486: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch024/validation_metrics.csv
# 2026-03-30 00:50:47,490: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch024/validation_results.p
# 2026-03-30 00:50:47,492: Epoch 24 average validation loss: 0.05419 -- Median validation metrics: avg_loss: 0.05419, NSE: 0.29179, KGE: 0.30272, Alpha-NSE: 0.60222, Beta-NSE: 0.11713, Pearson-r: 0.56577, RMSE: 2.20470, MSE: 4.86071, Beta-KGE: 1.27546
# # Epoch 25: 100%|██████████| 132/132 [00:03<00:00, 36.15it/s, Loss: 0.0134]
# 2026-03-30 00:50:51,147: Epoch 25 average loss: avg_loss: 0.04489, avg_total_loss: 0.04489
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.80it/s]
# 2026-03-30 00:50:55,078: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch025/validation_metrics.csv
# 2026-03-30 00:50:55,082: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch025/validation_results.p
# 2026-03-30 00:50:55,084: Epoch 25 average validation loss: 0.05610 -- Median validation metrics: avg_loss: 0.05610, NSE: 0.28530, KGE: 0.28555, Alpha-NSE: 0.61224, Beta-NSE: 0.16299, Pearson-r: 0.56693, RMSE: 2.23784, MSE: 5.00794, Beta-KGE: 1.35175
# # Epoch 26: 100%|██████████| 132/132 [00:03<00:00, 36.23it/s, Loss: 0.0194]
# 2026-03-30 00:50:58,731: Epoch 26 average loss: avg_loss: 0.04451, avg_total_loss: 0.04451
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.75it/s]
# 2026-03-30 00:51:02,745: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch026/validation_metrics.csv
# 2026-03-30 00:51:02,749: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch026/validation_results.p
# 2026-03-30 00:51:02,752: Epoch 26 average validation loss: 0.05367 -- Median validation metrics: avg_loss: 0.05367, NSE: 0.29093, KGE: 0.29815, Alpha-NSE: 0.59546, Beta-NSE: 0.11773, Pearson-r: 0.56449, RMSE: 2.21037, MSE: 4.88572, Beta-KGE: 1.28037
# # Epoch 27: 100%|██████████| 132/132 [00:03<00:00, 35.12it/s, Loss: 0.0721]
# 2026-03-30 00:51:06,514: Epoch 27 average loss: avg_loss: 0.04440, avg_total_loss: 0.04440
# # Validation: 100%|██████████| 11/11 [00:04<00:00,  2.61it/s]
# 2026-03-30 00:51:10,728: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch027/validation_metrics.csv
# 2026-03-30 00:51:10,732: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch027/validation_results.p
# 2026-03-30 00:51:10,735: Epoch 27 average validation loss: 0.05264 -- Median validation metrics: avg_loss: 0.05264, NSE: 0.29700, KGE: 0.33789, Alpha-NSE: 0.60202, Beta-NSE: 0.07519, Pearson-r: 0.56422, RMSE: 2.19344, MSE: 4.81119, Beta-KGE: 1.16578
# # Epoch 28: 100%|██████████| 132/132 [00:03<00:00, 35.84it/s, Loss: 0.0407]
# 2026-03-30 00:51:14,420: Epoch 28 average loss: avg_loss: 0.04473, avg_total_loss: 0.04473
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.79it/s]
# 2026-03-30 00:51:18,368: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch028/validation_metrics.csv
# 2026-03-30 00:51:18,372: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch028/validation_results.p
# 2026-03-30 00:51:18,374: Epoch 28 average validation loss: 0.05219 -- Median validation metrics: avg_loss: 0.05219, NSE: 0.29500, KGE: 0.33288, Alpha-NSE: 0.59592, Beta-NSE: 0.08803, Pearson-r: 0.56521, RMSE: 2.19160, MSE: 4.80311, Beta-KGE: 1.21398
# # Epoch 29: 100%|██████████| 132/132 [00:03<00:00, 36.21it/s, Loss: 0.0202]
# 2026-03-30 00:51:22,022: Epoch 29 average loss: avg_loss: 0.04390, avg_total_loss: 0.04390
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.79it/s]
# 2026-03-30 00:51:25,971: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch029/validation_metrics.csv
# 2026-03-30 00:51:25,974: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch029/validation_results.p
# 2026-03-30 00:51:25,977: Epoch 29 average validation loss: 0.05398 -- Median validation metrics: avg_loss: 0.05398, NSE: 0.28894, KGE: 0.31162, Alpha-NSE: 0.61439, Beta-NSE: 0.12113, Pearson-r: 0.56780, RMSE: 2.22426, MSE: 4.94732, Beta-KGE: 1.29378
# # Epoch 30: 100%|██████████| 132/132 [00:03<00:00, 36.44it/s, Loss: 0.0321]
# 2026-03-30 00:51:29,602: Epoch 30 average loss: avg_loss: 0.04444, avg_total_loss: 0.04444
# # Validation: 100%|██████████| 11/11 [00:03<00:00,  2.79it/s]
# 2026-03-30 00:51:33,554: Stored metrics at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch030/validation_metrics.csv
# 2026-03-30 00:51:33,558: Stored results at /home/azureuser/sky_workdir/extending_caravan/transfer_learning/runs/finetune_UY_basins_head_3003_004738/validation/model_epoch030/validation_results.p
# 2026-03-30 00:51:33,560: Epoch 30 average validation loss: 0.05399 -- Median validation metrics: avg_loss: 0.05399, NSE: 0.28772, KGE: 0.30892, Alpha-NSE: 0.60644, Beta-NSE: 0.12741, Pearson-r: 0.56640, RMSE: 2.22595, MSE: 4.95486, Beta-KGE: 1.30214

# %%
xr.open_dataset("../data/time_series/CAMELS_UY_6.nc")
# Out:
# <xarray.Dataset> Size: 498kB
# Dimensions:                           (date: 11322)
# Coordinates:
#   * date                              (date) datetime64[ns] 91kB 1989-01-01 ....
# Data variables:
#     temperature_2m_min                (date) float32 45kB ...
#     temperature_2m_max                (date) float32 45kB ...
#     surface_net_solar_radiation_mean  (date) float32 45kB ...
#     prcp_mm_day                       (date) float32 45kB ...
#     streamflow                        (date) float64 91kB ...
#     prcp_gauge_mm_day                 (date) float32 45kB ...
#     mswep_precipitation               (date) float32 45kB ...
#     chirps_precipitation              (date) float32 45kB ...
# Attributes:
#     precip_update:  Gauge, MSWEP and CHIRPS added where available

# %%
xr.open_dataset("../data/time_series/camels_01181000.nc")
# Out:
# <xarray.Dataset> Size: 321kB
# Dimensions:                           (date: 7305)
# Coordinates:
#     basin                             <U15 60B ...
#   * date                              (date) datetime64[ns] 58kB 1989-01-01 ....
# Data variables:
#     chirps_precipitation              (date) float32 29kB ...
#     era5land_total_precipitation      (date) float32 29kB ...
#     total_precipitation_sum           (date) float32 29kB ...
#     temperature_2m_max                (date) float32 29kB ...
#     temperature_2m_min                (date) float32 29kB ...
#     surface_net_solar_radiation_mean  (date) float32 29kB ...
#     streamflow                        (date) float32 29kB ...
#     mswep_precipitation               (date) float64 58kB ...
# Attributes:
#     Citation:  Funk, Chris, Pete Peterson, Martin Landsfeld, Diego Pedreros, ...
#     License:   To the extent possible under the law, Pete Peterson has waived...
#     Product:   CHIRPS
#     Released:  2024-11-18
#     Sources:   CHIRPS: Rainfall Estimates from Rain Gauge and Satellite Obser...
#     Units:     precipitation [mm]
#     Version:   1.1
