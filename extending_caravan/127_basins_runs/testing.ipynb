# %%
from neuralhydrology.nh_run import start_run, eval_run, finetune
from pathlib import Path
import pandas as pd
import pickle
import numpy as np
import yaml

# %%
RUN_DIR = Path("./runs")

# %%
# Find all directories starting with 'precip'
precip_dirs = [d for d in RUN_DIR.iterdir() if d.is_dir() and d.name.startswith("chirps")]

print(f"Found {len(precip_dirs)} directories: {[d.name for d in precip_dirs]}")
# Out:
# Found 16 directories: ['chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_0105_134115', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_3004_155951', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_3004_123641', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_3004_134421', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_3004_192304', 'chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_0105_090239', 'chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_0105_064335', 'chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_0105_145050', 'chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_0105_075306', 'chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_0105_112151', 'chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_0105_123134', 'chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_0105_101212', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_3004_181513', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_3004_170727', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_3004_145203', 'chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_3004_203050']

# %%
for run_dir in precip_dirs:

    # Skip if test folder already exists
    if (run_dir / "test").exists():
        print(f"Skipping {run_dir.name} — test folder already exists")
        continue

    config_path = run_dir / "config.yml"
    
    if not config_path.exists():
        print(f"Skipping {run_dir.name} — no config.yml found")
        continue
    
    print(f"\nProcessing {run_dir.name}...")
    
    # Read the config
    with open(config_path, 'r') as f:
        content = f.read()
    
    # Only add if not already present
    if "test_start_date" not in content:
        with open(config_path, 'a') as f:
            f.write("\ntest_start_date: 01/10/2009")
        print(f"  Added test_start_date")
    else:
        print(f"  test_start_date already present, skipping")

    if "test_end_date" not in content:
        with open(config_path, 'a') as f:
            f.write("\ntest_end_date: 30/09/2019")
        print(f"  Added test_end_date")
    else:
        print(f"  test_end_date already present, skipping")

    # Run evaluation
    print(f"  Running eval_run...")
    eval_run(run_dir=run_dir, period="test")
    print(f"  Done!")

print("\nAll runs completed!")
# Out:
# Skipping chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_0105_134115 — test folder already exists
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_3004_155951...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation: 100%|██████████| 127/127 [01:58<00:00,  1.07it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_3004_123641...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:09<00:00,  1.02s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_3004_134421...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:09<00:00,  1.02s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_3004_192304...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:10<00:00,  1.03s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_0105_090239...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:12<00:00,  1.05s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_0105_064335...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:12<00:00,  1.04s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_0105_145050...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:13<00:00,  1.05s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_0105_075306...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:13<00:00,  1.05s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_0105_112151...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:13<00:00,  1.05s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_0105_123134...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:13<00:00,  1.05s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_mswep_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_0105_101212...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:14<00:00,  1.06s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_3004_181513...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:10<00:00,  1.03s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_3004_170727...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:10<00:00,  1.03s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_3004_145203...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:11<00:00,  1.03s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing chirps_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_3004_203050...
#   test_start_date already present, skipping
#   test_end_date already present, skipping
#   Running eval_run...
# # Evaluation: 100%|██████████| 127/127 [02:10<00:00,  1.03s/it]
#   Done!
#
# All runs completed!
