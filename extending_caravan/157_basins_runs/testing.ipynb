# %%
from neuralhydrology.nh_run import start_run, eval_run, finetune
from pathlib import Path

# %%
run_dir = Path("./runs/camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_2604_155636")

# %%
eval_run(run_dir=run_dir, period="test")
# Out:
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:   0%|          | 0/157 [00:00<?, ?it/s]
# The following basins had not enough valid target values to calculate a standard deviation: camels_01411300. NSE loss values for this basin will be NaN.
# # Evaluation:   1%|          | 1/157 [00:02<06:32,  2.52s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_01491000. NSE loss values for this basin will be NaN.
# # Evaluation:   1%|▏         | 2/157 [00:04<05:20,  2.07s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_01644000. NSE loss values for this basin will be NaN.
# # Evaluation:   2%|▏         | 3/157 [00:06<04:56,  1.93s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_01664000. NSE loss values for this basin will be NaN.
# # Evaluation:   3%|▎         | 4/157 [00:07<04:44,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_01667500. NSE loss values for this basin will be NaN.
# # Evaluation:   3%|▎         | 5/157 [00:09<04:36,  1.82s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02028500. NSE loss values for this basin will be NaN.
# # Evaluation:   4%|▍         | 6/157 [00:11<04:31,  1.80s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02038850. NSE loss values for this basin will be NaN.
# # Evaluation:   4%|▍         | 7/157 [00:13<04:26,  1.78s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02051500. NSE loss values for this basin will be NaN.
# # Evaluation:   5%|▌         | 8/157 [00:14<04:28,  1.80s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02053200. NSE loss values for this basin will be NaN.
# # Evaluation:   6%|▌         | 9/157 [00:16<04:22,  1.78s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02053800. NSE loss values for this basin will be NaN.
# # Evaluation:   6%|▋         | 10/157 [00:18<04:18,  1.76s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02056900. NSE loss values for this basin will be NaN.
# # Evaluation:   7%|▋         | 11/157 [00:20<04:14,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02059500. NSE loss values for this basin will be NaN.
# # Evaluation:   8%|▊         | 12/157 [00:21<04:11,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02069700. NSE loss values for this basin will be NaN.
# # Evaluation:   8%|▊         | 13/157 [00:23<04:09,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02070000. NSE loss values for this basin will be NaN.
# # Evaluation:   9%|▉         | 14/157 [00:25<04:06,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02074500. NSE loss values for this basin will be NaN.
# # Evaluation:  10%|▉         | 15/157 [00:26<04:03,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02077200. NSE loss values for this basin will be NaN.
# # Evaluation:  10%|█         | 16/157 [00:28<04:01,  1.71s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02081500. NSE loss values for this basin will be NaN.
# # Evaluation:  11%|█         | 17/157 [00:30<03:58,  1.70s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02092500. NSE loss values for this basin will be NaN.
# # Evaluation:  11%|█▏        | 18/157 [00:31<03:56,  1.70s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02102908. NSE loss values for this basin will be NaN.
# # Evaluation:  12%|█▏        | 19/157 [00:33<04:00,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02111180. NSE loss values for this basin will be NaN.
# # Evaluation:  13%|█▎        | 20/157 [00:35<03:57,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02111500. NSE loss values for this basin will be NaN.
# # Evaluation:  13%|█▎        | 21/157 [00:37<03:53,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02112120. NSE loss values for this basin will be NaN.
# # Evaluation:  14%|█▍        | 22/157 [00:38<03:52,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02112360. NSE loss values for this basin will be NaN.
# # Evaluation:  15%|█▍        | 23/157 [00:40<03:49,  1.71s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02118500. NSE loss values for this basin will be NaN.
# # Evaluation:  15%|█▌        | 24/157 [00:42<03:47,  1.71s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02125000. NSE loss values for this basin will be NaN.
# # Evaluation:  16%|█▌        | 25/157 [00:44<03:51,  1.76s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02128000. NSE loss values for this basin will be NaN.
# # Evaluation:  17%|█▋        | 26/157 [00:45<03:52,  1.77s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02137727. NSE loss values for this basin will be NaN.
# # Evaluation:  17%|█▋        | 27/157 [00:47<03:53,  1.80s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02140991. NSE loss values for this basin will be NaN.
# # Evaluation:  18%|█▊        | 28/157 [00:49<03:58,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02143000. NSE loss values for this basin will be NaN.
# # Evaluation:  18%|█▊        | 29/157 [00:51<03:56,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02143040. NSE loss values for this basin will be NaN.
# # Evaluation:  19%|█▉        | 30/157 [00:53<03:53,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02149000. NSE loss values for this basin will be NaN.
# # Evaluation:  20%|█▉        | 31/157 [00:55<03:52,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02152100. NSE loss values for this basin will be NaN.
# # Evaluation:  20%|██        | 32/157 [00:57<03:50,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02177000. NSE loss values for this basin will be NaN.
# # Evaluation:  21%|██        | 33/157 [00:58<03:48,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02178400. NSE loss values for this basin will be NaN.
# # Evaluation:  22%|██▏       | 34/157 [01:00<03:47,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02193340. NSE loss values for this basin will be NaN.
# # Evaluation:  22%|██▏       | 35/157 [01:02<03:45,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02202600. NSE loss values for this basin will be NaN.
# # Evaluation:  23%|██▎       | 36/157 [01:04<03:43,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02212600. NSE loss values for this basin will be NaN.
# # Evaluation:  24%|██▎       | 37/157 [01:06<03:41,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02215100. NSE loss values for this basin will be NaN.
# # Evaluation:  24%|██▍       | 38/157 [01:08<03:40,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02216180. NSE loss values for this basin will be NaN.
# # Evaluation:  25%|██▍       | 39/157 [01:10<03:38,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02221525. NSE loss values for this basin will be NaN.
# # Evaluation:  25%|██▌       | 40/157 [01:11<03:36,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02231000. NSE loss values for this basin will be NaN.
# # Evaluation:  26%|██▌       | 41/157 [01:13<03:40,  1.90s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02246000. NSE loss values for this basin will be NaN.
# # Evaluation:  27%|██▋       | 42/157 [01:15<03:36,  1.89s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02296500. NSE loss values for this basin will be NaN.
# # Evaluation:  27%|██▋       | 43/157 [01:17<03:33,  1.87s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02297155. NSE loss values for this basin will be NaN.
# # Evaluation:  28%|██▊       | 44/157 [01:19<03:30,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02297310. NSE loss values for this basin will be NaN.
# # Evaluation:  29%|██▊       | 45/157 [01:21<03:28,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02298123. NSE loss values for this basin will be NaN.
# # Evaluation:  29%|██▉       | 46/157 [01:23<03:25,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02298608. NSE loss values for this basin will be NaN.
# # Evaluation:  30%|██▉       | 47/157 [01:25<03:23,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02299950. NSE loss values for this basin will be NaN.
# # Evaluation:  31%|███       | 48/157 [01:26<03:20,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02300700. NSE loss values for this basin will be NaN.
# # Evaluation:  31%|███       | 49/157 [01:28<03:18,  1.83s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02342933. NSE loss values for this basin will be NaN.
# # Evaluation:  32%|███▏      | 50/157 [01:30<03:15,  1.83s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02349900. NSE loss values for this basin will be NaN.
# # Evaluation:  32%|███▏      | 51/157 [01:32<03:13,  1.83s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02350900. NSE loss values for this basin will be NaN.
# # Evaluation:  33%|███▎      | 52/157 [01:34<03:17,  1.88s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02361000. NSE loss values for this basin will be NaN.
# # Evaluation:  34%|███▍      | 53/157 [01:36<03:14,  1.87s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02363000. NSE loss values for this basin will be NaN.
# # Evaluation:  34%|███▍      | 54/157 [01:38<03:12,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02369800. NSE loss values for this basin will be NaN.
# # Evaluation:  35%|███▌      | 55/157 [01:39<03:09,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02371500. NSE loss values for this basin will be NaN.
# # Evaluation:  36%|███▌      | 56/157 [01:41<03:07,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02372250. NSE loss values for this basin will be NaN.
# # Evaluation:  36%|███▋      | 57/157 [01:43<03:05,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02374500. NSE loss values for this basin will be NaN.
# # Evaluation:  37%|███▋      | 58/157 [01:45<03:02,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02381600. NSE loss values for this basin will be NaN.
# # Evaluation:  38%|███▊      | 59/157 [01:47<03:01,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02384540. NSE loss values for this basin will be NaN.
# # Evaluation:  38%|███▊      | 60/157 [01:49<02:59,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02395120. NSE loss values for this basin will be NaN.
# # Evaluation:  39%|███▉      | 61/157 [01:50<02:57,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02415000. NSE loss values for this basin will be NaN.
# # Evaluation:  39%|███▉      | 62/157 [01:52<02:55,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02427250. NSE loss values for this basin will be NaN.
# # Evaluation:  40%|████      | 63/157 [01:54<02:53,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02430085. NSE loss values for this basin will be NaN.
# # Evaluation:  41%|████      | 64/157 [01:56<02:52,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02450250. NSE loss values for this basin will be NaN.
# # Evaluation:  41%|████▏     | 65/157 [01:58<02:55,  1.90s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02464000. NSE loss values for this basin will be NaN.
# # Evaluation:  42%|████▏     | 66/157 [02:00<02:51,  1.89s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02464360. NSE loss values for this basin will be NaN.
# # Evaluation:  43%|████▎     | 67/157 [02:02<02:48,  1.88s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02465493. NSE loss values for this basin will be NaN.
# # Evaluation:  43%|████▎     | 68/157 [02:04<02:46,  1.87s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02469800. NSE loss values for this basin will be NaN.
# # Evaluation:  44%|████▍     | 69/157 [02:05<02:43,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02472000. NSE loss values for this basin will be NaN.
# # Evaluation:  45%|████▍     | 70/157 [02:07<02:41,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02472500. NSE loss values for this basin will be NaN.
# # Evaluation:  45%|████▌     | 71/157 [02:09<02:39,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02479155. NSE loss values for this basin will be NaN.
# # Evaluation:  46%|████▌     | 72/157 [02:11<02:38,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02479300. NSE loss values for this basin will be NaN.
# # Evaluation:  46%|████▋     | 73/157 [02:13<02:35,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02479560. NSE loss values for this basin will be NaN.
# # Evaluation:  47%|████▋     | 74/157 [02:15<02:33,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02481000. NSE loss values for this basin will be NaN.
# # Evaluation:  48%|████▊     | 75/157 [02:16<02:31,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_02481510. NSE loss values for this basin will be NaN.
# # Evaluation:  48%|████▊     | 76/157 [02:18<02:32,  1.89s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03170000. NSE loss values for this basin will be NaN.
# # Evaluation:  49%|████▉     | 77/157 [02:20<02:30,  1.88s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03237280. NSE loss values for this basin will be NaN.
# # Evaluation:  50%|████▉     | 78/157 [02:22<02:27,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03280700. NSE loss values for this basin will be NaN.
# # Evaluation:  50%|█████     | 79/157 [02:24<02:25,  1.87s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03281500. NSE loss values for this basin will be NaN.
# # Evaluation:  51%|█████     | 80/157 [02:26<02:23,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03285000. NSE loss values for this basin will be NaN.
# # Evaluation:  52%|█████▏    | 81/157 [02:28<02:20,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03384450. NSE loss values for this basin will be NaN.
# # Evaluation:  52%|█████▏    | 82/157 [02:30<02:18,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03439000. NSE loss values for this basin will be NaN.
# # Evaluation:  53%|█████▎    | 83/157 [02:31<02:16,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03455500. NSE loss values for this basin will be NaN.
# # Evaluation:  54%|█████▎    | 84/157 [02:33<02:15,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03456500. NSE loss values for this basin will be NaN.
# # Evaluation:  54%|█████▍    | 85/157 [02:35<02:13,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03460000. NSE loss values for this basin will be NaN.
# # Evaluation:  55%|█████▍    | 86/157 [02:37<02:16,  1.92s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03463300. NSE loss values for this basin will be NaN.
# # Evaluation:  55%|█████▌    | 87/157 [02:39<02:12,  1.90s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03498500. NSE loss values for this basin will be NaN.
# # Evaluation:  56%|█████▌    | 88/157 [02:41<02:09,  1.88s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03500000. NSE loss values for this basin will be NaN.
# # Evaluation:  57%|█████▋    | 89/157 [02:43<02:07,  1.88s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03500240. NSE loss values for this basin will be NaN.
# # Evaluation:  57%|█████▋    | 90/157 [02:45<02:05,  1.88s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03504000. NSE loss values for this basin will be NaN.
# # Evaluation:  58%|█████▊    | 91/157 [02:46<02:03,  1.87s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03574500. NSE loss values for this basin will be NaN.
# # Evaluation:  59%|█████▊    | 92/157 [02:48<02:00,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03592718. NSE loss values for this basin will be NaN.
# # Evaluation:  59%|█████▉    | 93/157 [02:50<01:58,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_03604000. NSE loss values for this basin will be NaN.
# # Evaluation:  60%|█████▉    | 94/157 [02:52<01:56,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_05593575. NSE loss values for this basin will be NaN.
# # Evaluation:  61%|██████    | 95/157 [02:54<01:54,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_05595730. NSE loss values for this basin will be NaN.
# # Evaluation:  61%|██████    | 96/157 [02:56<01:50,  1.81s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06917000. NSE loss values for this basin will be NaN.
# # Evaluation:  62%|██████▏   | 97/157 [02:57<01:47,  1.79s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06918460. NSE loss values for this basin will be NaN.
# # Evaluation:  62%|██████▏   | 98/157 [02:59<01:44,  1.77s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06919500. NSE loss values for this basin will be NaN.
# # Evaluation:  63%|██████▎   | 99/157 [03:01<01:41,  1.75s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06921070. NSE loss values for this basin will be NaN.
# # Evaluation:  64%|██████▎   | 100/157 [03:02<01:39,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06921200. NSE loss values for this basin will be NaN.
# # Evaluation:  64%|██████▍   | 101/157 [03:04<01:37,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07057500. NSE loss values for this basin will be NaN.
# # Evaluation:  65%|██████▍   | 102/157 [03:06<01:34,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07060710. NSE loss values for this basin will be NaN.
# # Evaluation:  66%|██████▌   | 103/157 [03:08<01:33,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07066000. NSE loss values for this basin will be NaN.
# # Evaluation:  66%|██████▌   | 104/157 [03:09<01:30,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07142300. NSE loss values for this basin will be NaN.
# # Evaluation:  67%|██████▋   | 105/157 [03:11<01:28,  1.71s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07145700. NSE loss values for this basin will be NaN.
# # Evaluation:  68%|██████▊   | 106/157 [03:13<01:27,  1.71s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07167500. NSE loss values for this basin will be NaN.
# # Evaluation:  68%|██████▊   | 107/157 [03:14<01:25,  1.71s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07184000. NSE loss values for this basin will be NaN.
# # Evaluation:  69%|██████▉   | 108/157 [03:16<01:25,  1.75s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07195800. NSE loss values for this basin will be NaN.
# # Evaluation:  69%|██████▉   | 109/157 [03:18<01:23,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07196900. NSE loss values for this basin will be NaN.
# # Evaluation:  70%|███████   | 110/157 [03:20<01:21,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07197000. NSE loss values for this basin will be NaN.
# # Evaluation:  71%|███████   | 111/157 [03:21<01:19,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07263295. NSE loss values for this basin will be NaN.
# # Evaluation:  71%|███████▏  | 112/157 [03:23<01:18,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07291000. NSE loss values for this basin will be NaN.
# # Evaluation:  72%|███████▏  | 113/157 [03:25<01:16,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07299670. NSE loss values for this basin will be NaN.
# # Evaluation:  73%|███████▎  | 114/157 [03:27<01:14,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07301410. NSE loss values for this basin will be NaN.
# # Evaluation:  73%|███████▎  | 115/157 [03:28<01:12,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07340300. NSE loss values for this basin will be NaN.
# # Evaluation:  74%|███████▍  | 116/157 [03:30<01:11,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07346045. NSE loss values for this basin will be NaN.
# # Evaluation:  75%|███████▍  | 117/157 [03:32<01:09,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07359610. NSE loss values for this basin will be NaN.
# # Evaluation:  75%|███████▌  | 118/157 [03:34<01:07,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07362100. NSE loss values for this basin will be NaN.
# # Evaluation:  76%|███████▌  | 119/157 [03:35<01:05,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07362587. NSE loss values for this basin will be NaN.
# # Evaluation:  76%|███████▋  | 120/157 [03:37<01:05,  1.77s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_07375000. NSE loss values for this basin will be NaN.
# # Evaluation:  77%|███████▋  | 121/157 [03:39<01:03,  1.76s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08013000. NSE loss values for this basin will be NaN.
# # Evaluation:  78%|███████▊  | 122/157 [03:41<01:01,  1.75s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08014500. NSE loss values for this basin will be NaN.
# # Evaluation:  78%|███████▊  | 123/157 [03:42<00:59,  1.75s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08023080. NSE loss values for this basin will be NaN.
# # Evaluation:  79%|███████▉  | 124/157 [03:44<00:57,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08066200. NSE loss values for this basin will be NaN.
# # Evaluation:  80%|███████▉  | 125/157 [03:46<00:55,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08066300. NSE loss values for this basin will be NaN.
# # Evaluation:  80%|████████  | 126/157 [03:48<00:53,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08070000. NSE loss values for this basin will be NaN.
# # Evaluation:  81%|████████  | 127/157 [03:49<00:51,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08070200. NSE loss values for this basin will be NaN.
# # Evaluation:  82%|████████▏ | 128/157 [03:51<00:50,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08086212. NSE loss values for this basin will be NaN.
# # Evaluation:  82%|████████▏ | 129/157 [03:53<00:48,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08086290. NSE loss values for this basin will be NaN.
# # Evaluation:  83%|████████▎ | 130/157 [03:54<00:46,  1.72s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08101000. NSE loss values for this basin will be NaN.
# # Evaluation:  83%|████████▎ | 131/157 [03:56<00:45,  1.76s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08103900. NSE loss values for this basin will be NaN.
# # Evaluation:  84%|████████▍ | 132/157 [03:58<00:43,  1.74s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08104900. NSE loss values for this basin will be NaN.
# # Evaluation:  85%|████████▍ | 133/157 [04:00<00:41,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08150800. NSE loss values for this basin will be NaN.
# # Evaluation:  85%|████████▌ | 134/157 [04:01<00:39,  1.73s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08158700. NSE loss values for this basin will be NaN.
# # Evaluation:  86%|████████▌ | 135/157 [04:03<00:39,  1.79s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08158810. NSE loss values for this basin will be NaN.
# # Evaluation:  87%|████████▋ | 136/157 [04:05<00:37,  1.80s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08164300. NSE loss values for this basin will be NaN.
# # Evaluation:  87%|████████▋ | 137/157 [04:07<00:36,  1.82s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08164600. NSE loss values for this basin will be NaN.
# # Evaluation:  88%|████████▊ | 138/157 [04:09<00:34,  1.83s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08165300. NSE loss values for this basin will be NaN.
# # Evaluation:  89%|████████▊ | 139/157 [04:11<00:33,  1.83s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08171300. NSE loss values for this basin will be NaN.
# # Evaluation:  89%|████████▉ | 140/157 [04:13<00:31,  1.88s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08175000. NSE loss values for this basin will be NaN.
# # Evaluation:  90%|████████▉ | 141/157 [04:14<00:28,  1.77s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08176900. NSE loss values for this basin will be NaN.
# # Evaluation:  90%|█████████ | 142/157 [04:16<00:27,  1.80s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08178880. NSE loss values for this basin will be NaN.
# # Evaluation:  91%|█████████ | 143/157 [04:18<00:25,  1.82s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08189500. NSE loss values for this basin will be NaN.
# # Evaluation:  92%|█████████▏| 144/157 [04:20<00:23,  1.82s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08190000. NSE loss values for this basin will be NaN.
# # Evaluation:  92%|█████████▏| 145/157 [04:22<00:21,  1.83s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08190500. NSE loss values for this basin will be NaN.
# # Evaluation:  93%|█████████▎| 146/157 [04:23<00:20,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08194200. NSE loss values for this basin will be NaN.
# # Evaluation:  94%|█████████▎| 147/157 [04:25<00:17,  1.76s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08195000. NSE loss values for this basin will be NaN.
# # Evaluation:  94%|█████████▍| 148/157 [04:27<00:16,  1.78s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08196000. NSE loss values for this basin will be NaN.
# # Evaluation:  95%|█████████▍| 149/157 [04:29<00:14,  1.80s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08198500. NSE loss values for this basin will be NaN.
# # Evaluation:  96%|█████████▌| 150/157 [04:31<00:13,  1.87s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08200000. NSE loss values for this basin will be NaN.
# # Evaluation:  96%|█████████▌| 151/157 [04:33<00:11,  1.86s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_08202700. NSE loss values for this basin will be NaN.
# # Evaluation:  97%|█████████▋| 152/157 [04:34<00:09,  1.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_09484600. NSE loss values for this basin will be NaN.
# # Evaluation:  97%|█████████▋| 153/157 [04:36<00:07,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_09497980. NSE loss values for this basin will be NaN.
# # Evaluation:  98%|█████████▊| 154/157 [04:38<00:05,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_09510200. NSE loss values for this basin will be NaN.
# # Evaluation:  99%|█████████▊| 155/157 [04:40<00:03,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_11141280. NSE loss values for this basin will be NaN.
# # Evaluation:  99%|█████████▉| 156/157 [04:42<00:01,  1.84s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_11151300. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 157/157 [04:44<00:00,  1.81s/it]
