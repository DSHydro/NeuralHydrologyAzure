# %%
from neuralhydrology.nh_run import start_run, eval_run, finetune
from pathlib import Path
import pandas as pd
import pickle
import numpy as np
import yaml

# %%
RUN_DIR = Path("./runs")

# %%
# Find all directories starting with 'precip'
precip_dirs = [d for d in RUN_DIR.iterdir() if d.is_dir()]  #and d.name.startswith("precip")]

print(f"Found {len(precip_dirs)} directories: {[d.name for d in precip_dirs]}")
# Out:
# Found 120 directories: ['precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_222_2904_110606', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_111_2904_110014', 'precip_prcp_mm_day_prcp_chirps_mm_day_seed_777_2904_083014', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_222_2904_084721', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_091010', 'precip_prcp_mswep_mm_day_seed_333_2804_223907', 'precip_prcp_mswep_mm_day_seed_222_2804_223324', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_010934', 'precip_prcp_gauge_mm_day_seed_777_2302_080217', 'precip_prcp_chirps_mm_day_seed_777_2904_074449', 'precip_prcp_gauge_mm_day_seed_666_2302_075627', 'precip_prcp_mm_day_seed_444_2202_190226', 'precip_prcp_mm_day_prcp_gauge_mm_day_seed_888_2302_091905', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_131125', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_013333', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_104233', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_123501', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_004557', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_555_2904_112344', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_004009', 'precip_prcp_gauge_mm_day_seed_222_2202_195846', 'precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_888_2904_100720', 'precip_prcp_chirps_mm_day_seed_666_2904_073913', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_005739', 'precip_prcp_chirps_mm_day_seed_222_2904_071648', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_444_2804_234741', 'precip_prcp_mm_day_seed_555_2302_064058', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_114732', 'precip_prcp_mswep_mm_day_seed_555_2804_225032', 'precip_prcp_mswep_mm_day_seed_111_2804_222722', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_003420', 'precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_666_2904_095554', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_555_2904_090427', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_012732', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_888_2904_001101', 'precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_012130', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_444_2904_085845', 'precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_555_2904_095011', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_121120', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_120525', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_222_2904_101859', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_122903', 'precip_prcp_gauge_mm_day_seed_444_2202_201003', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_130523', 'precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_333_2904_002831', 'precip_prcp_mm_day_prcp_chirps_mm_day_seed_444_2904_081305', 'precip_prcp_mm_day_prcp_gauge_mm_day_seed_333_2202_211306', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_111_2904_084139', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_333_2804_234152', 'precip_prcp_gauge_mm_day_seed_555_2302_075038', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_666_2904_112941', 'precip_prcp_gauge_mm_day_seed_888_2302_080806', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_125314', 'precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_122309', 'precip_prcp_mm_day_seed_888_2302_065823', 'precip_prcp_mm_day_prcp_mswep_mm_day_seed_222_2804_233604', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_333_2904_111159', 'precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_777_2904_113538', 'precip_prcp_mm_day_prcp_chirps_mm_day_seed_555_2904_081848' ...

# %%
for run_dir in precip_dirs:

    # Skip if test folder already exists
    # if (run_dir / "test").exists():
    #     print(f"Skipping {run_dir.name} — test folder already exists")
    #     continue

    config_path = run_dir / "config.yml"
    
    if not config_path.exists():
        print(f"Skipping {run_dir.name} — no config.yml found")
        continue
    
    print(f"\nProcessing {run_dir.name}...")
    
    # Read the config
    with open(config_path, 'r') as f:
        content = f.read()
    
    # # Only add if not already present
    # if "test_start_date" not in content:
    #     with open(config_path, 'a') as f:
    #         f.write("\ntest_start_date: 01/10/2009")
    #     print(f"  Added test_start_date")
    # else:
    #     print(f"  test_start_date already present, skipping")

    # if "test_end_date" not in content:
    #     with open(config_path, 'a') as f:
    #         f.write("\ntest_end_date: 30/09/2019")
    #     print(f"  Added test_end_date")
    # else:
    #     print(f"  test_end_date already present, skipping")
    
    content = content.replace("test_start_date: 01/10/2009", "test_start_date: 01/10/2008")
    content = content.replace("test_end_date: 30/09/2019", "test_end_date: 30/09/2014")
    
    with open(config_path, 'w') as f:
        f.write(content)

    # Run evaluation
    print(f"  Running eval_run...")
    eval_run(run_dir=run_dir, period="test")
    print(f"  Done!")

print("\nAll runs completed!")
# Out:
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_222_2904_110606...
#   Running eval_run...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:  18%|█▊        | 2/11 [00:01<00:05,  1.57it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:04<00:00,  2.53it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_111_2904_110014...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.73it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.17it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_seed_777_2904_083014...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.88it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.39it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_222_2904_084721...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.87it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.28it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_091010...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.89it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.27it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_seed_333_2804_223907...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.07it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.47it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_seed_222_2804_223324...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.02it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.28it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_010934...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.60it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.15it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_gauge_mm_day_seed_777_2302_080217...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.01it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.38it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_seed_777_2904_074449...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.08it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.50it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_gauge_mm_day_seed_666_2302_075627...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.40it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.39it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_seed_444_2202_190226...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.02it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.39it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_gauge_mm_day_seed_888_2302_091905...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.85it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.26it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_777_2904_131125...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.59it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.07it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_013333...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.73it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.17it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_666_2904_104233...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.72it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.26it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_123501...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.09it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.07it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_666_2904_004557...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.08it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.26it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_555_2904_112344...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.73it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.17it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_004009...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.88it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.27it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_gauge_mm_day_seed_222_2202_195846...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.02it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.50it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_888_2904_100720...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.25it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.27it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_seed_666_2904_073913...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.08it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.39it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_005739...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.89it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.26it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_seed_222_2904_071648...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.03it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.51it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_mswep_mm_day_seed_444_2804_234741...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.07it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.19it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_seed_555_2302_064058...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.84it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.33it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_114732...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.72it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.17it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_seed_555_2804_225032...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.03it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.38it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_seed_111_2804_222722...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.06it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.50it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_444_2904_003420...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.86it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.27it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_666_2904_095554...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.89it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.27it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_555_2904_090427...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.87it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.26it/s]
# ...
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_222_2904_002241...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.09it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.26it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_seed_888_2904_075024...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.03it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.37it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_111_2904_001651...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.83it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.24it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_seed_444_2904_103044...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.70it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.15it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_555_2904_125917...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.58it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.06it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mswep_mm_day_seed_777_2804_230155...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.02it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.49it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_chirps_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_333_2904_124709...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.59it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.06it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_gauge_mm_day_seed_111_2202_195308...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.01it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.37it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_prcp_gauge_mm_day_seed_222_2904_093300...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.83it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.25it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_chirps_mm_day_seed_555_2904_073338...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  4.00it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  3.48it/s]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing precip_prcp_mm_day_prcp_mswep_mm_day_prcp_gauge_mm_day_seed_888_2904_014533...
#   Running eval_run...
# # Evaluation:  18%|█▊        | 2/11 [00:00<00:02,  3.01it/s]
# The following basins had not enough valid target values to calculate a standard deviation: CAMELS_UY_15. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 11/11 [00:03<00:00,  2.99it/s]
#   Done!
#
# All runs completed!
