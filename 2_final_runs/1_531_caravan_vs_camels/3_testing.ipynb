# %%
from neuralhydrology.nh_run import start_run, eval_run, finetune
from pathlib import Path
import pandas as pd
import pickle
import numpy as np
import yaml

# %%
RUN_DIR = Path("./runs")

# %%
# Find all directories starting with 'precip'
precip_dirs = [d for d in RUN_DIR.iterdir() if d.is_dir()]

print(f"Found {len(precip_dirs)} directories: {[d.name for d in precip_dirs]}")
# Out:
# Found 16 directories: ['total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_2404_120137', 'total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_2504_143159', 'total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_2404_230020', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_2304_041450', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_2404_014030', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_2204_175151', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_2304_092510', 'total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_2504_194621', 'total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_2504_041052', 'total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_2404_171225', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_2304_143622', 'total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_2204_112806', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_2404_065130', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_2204_230424', 'total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_2504_092107', 'camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_2204_062451']

# %%
for run_dir in precip_dirs:
    config_path = run_dir / "config.yml"
    
    if not config_path.exists():
        print(f"Skipping {run_dir.name} — no config.yml found")
        continue
    
    print(f"\nProcessing {run_dir.name}...")
    
    # Read the config
    with open(config_path, 'r') as f:
        content = f.read()
    
    # Only add if not already present
    if "test_start_date" not in content:
        with open(config_path, 'a') as f:
            f.write("\ntest_start_date: 01/10/2009")
        print(f"  Added test_start_date")
    else:
        print(f"  test_start_date already present, skipping")

    if "test_end_date" not in content:
        with open(config_path, 'a') as f:
            f.write("\ntest_end_date: 30/09/2019")
        print(f"  Added test_end_date")
    else:
        print(f"  test_end_date already present, skipping")

    # Run evaluation
    print(f"  Running eval_run...")
    eval_run(run_dir=run_dir, period="test")
    print(f"  Done!")

print("\nAll runs completed!")
# Out:
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_2404_120137...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:  54%|█████▍    | 287/531 [10:41<07:18,  1.80s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [19:30<00:00,  2.20s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_2504_143159...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [10:29<07:25,  1.82s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [19:42<00:00,  2.23s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_2404_230020...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [10:28<07:13,  1.78s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [19:35<00:00,  2.21s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_2304_041450...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [10:43<09:41,  2.38s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [19:37<00:00,  2.22s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed777_2404_014030...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [10:50<09:16,  2.28s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [19:31<00:00,  2.21s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed222_2204_175151...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [09:30<09:07,  2.25s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [19:18<00:00,  2.18s/it]
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed555_2304_092510...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [15:37<11:59,  2.95s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [27:43<00:00,  3.13s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_2504_194621...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [14:54<12:03,  2.97s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [27:52<00:00,  3.15s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_2504_041052...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [14:43<21:58,  5.40s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [27:49<00:00,  3.14s/it]
#   Done!
#
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_2404_171225...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:  54%|█████▍    | 287/531 [14:49<12:14,  3.01s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [27:40<00:00,  3.13s/it]
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed666_2304_143622...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [14:48<13:10,  3.24s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [27:54<00:00,  3.15s/it]
#   Done!
#
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_2204_112806...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [15:26<16:43,  4.11s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [28:03<00:00,  3.17s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed888_2404_065130...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [14:29<11:14,  2.77s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [27:18<00:00,  3.09s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed333_2204_230424...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [15:01<11:52,  2.92s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [26:43<00:00,  3.02s/it]
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#   Done!
#
# Processing total_precipitation_sum_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed444_2504_092107...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# # Evaluation:  54%|█████▍    | 287/531 [13:42<07:25,  1.83s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [24:58<00:00,  2.82s/it]
#   Done!
#
# Processing camels_precipitation_seq_270_1_epochs_30_hidden_256_dropout_04_fb_5_seed111_2204_062451...
#   Added test_start_date
#   Added test_end_date
#   Running eval_run...
# /home/azureuser/miniconda3/envs/neuralhydrology/lib/python3.10/site-packages/neuralhydrology/evaluation/tester.py:143: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
# # Evaluation:  54%|█████▍    | 287/531 [13:09<15:39,  3.85s/it]
# The following basins had not enough valid target values to calculate a standard deviation: camels_06291500. NSE loss values for this basin will be NaN.
# # Evaluation: 100%|██████████| 531/531 [24:36<00:00,  2.78s/it]
#   Done!
#
# All runs completed!
